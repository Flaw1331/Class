# %%
import json
import tweepy 
import os

# %%
api_dir = os.path.dirname(os.path.dirname(os.path.dirname(os.path.dirname(os.path.dirname(os.path.realpath('__file__'))))))
file_name = os.path.join(api_dir, "api_keys.json")
data = json.load(open(file_name))

consumer_key = data['twitter_consumer_key']
consumer_secret = data['twitter_consumer_secret']
access_token = data['twitter_access_token']
access_token_secret = data['twitter_access_token_secret']

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Search for People Tweeting about Katy Perry
search_term = "Katy Perry"


# Retrieve 100 tweets
public_tweets = api.search(search_term, count=100)

# %%
#public_tweets['statuses'][0]
print(json.dumps(public_tweets, sort_keys=True, indent=4, separators=(',', ': ')))
# Out:
# {
#     "search_metadata": {
#         "completed_in": 0.126,
#         "count": 100,
#         "max_id": 956698969597464576,
#         "max_id_str": "956698969597464576",
#         "next_results": "?max_id=956695712003186687&q=Katy%20Perry&count=100&include_entities=1",
#         "query": "Katy+Perry",
#         "refresh_url": "?since_id=956698969597464576&q=Katy%20Perry&include_entities=1",
#         "since_id": 0,
#         "since_id_str": "0"
#     },
#     "statuses": [
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Fri Jan 26 01:23:03 +0000 2018",
#             "entities": {
#                 "hashtags": [],
#                 "media": [
#                     {
#                         "display_url": "pic.twitter.com/wOvzeCu1HI",
#                         "expanded_url": "https://twitter.com/kcestrabao/status/933835494777028608/video/1",
#                         "id": 933834639495647233,
#                         "id_str": "933834639495647233",
#                         "indices": [
#                             59,
#                             82
#                         ],
#                         "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/933834639495647233/pu/img/lsyA0AAqKr4-JgPM.jpg",
#                         "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/933834639495647233/pu/img/lsyA0AAqKr4-JgPM.jpg",
#                         "sizes": {
#                             "large": {
#                                 "h": 720,
#                                 "resize": "fit",
#                                 "w": 1280
#                             },
#                             "medium": {
#                                 "h": 675,
#                                 "resize": "fit",
#                                 "w": 1200
#                             },
#                             "small": {
#                                 "h": 383,
#                                 "resize": "fit",
#                                 "w": 680
#                             },
#                             "thumb": {
#                                 "h": 150,
#                                 "resize": "crop",
#                                 "w": 150
#                             }
#                         },
#                         "source_status_id": 933835494777028608,
#                         "source_status_id_str": "933835494777028608",
#                         "source_user_id": 4112816181,
#                         "source_user_id_str": "4112816181",
#                         "type": "photo",
#                         "url": "https://t.co/wOvzeCu1HI"
#                     }
#                 ],
#                 "symbols": [],
#                 "urls": [],
#                 "user_mentions": [
#                     {
#                         "id": 1430664355,
#                         "id_str": "1430664355",
#                         "indices": [
#                             3,
#                             19
#                         ],
#                         "name": "lara",
#                         "screen_name": "rosescamilizers"
#                     }
#                 ]
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "additional_media_info": {
#                             "monetizable": false
#                         },
#                         "display_url": "pic.twitter.com/wOvzeCu1HI",
#                         "expanded_url": "https://twitter.com/kcestrabao/status/933835494777028608/video/1",
#                         "id": 933834639495647233,
#                         "id_str": "933834639495647233",
#                         "indices": [
#                             59,
#                             82
#                         ],
#                         "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/933834639495647233/pu/img/lsyA0AAqKr4-JgPM.jpg",
#                         "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/933834639495647233/pu/img/lsyA0AAqKr4-JgPM.jpg",
#                         "sizes": {
#                             "large": {
#                                 "h": 720,
#                                 "resize": "fit",
#                                 "w": 1280
#                             },
#                             "medium": {
#                                 "h": 675,
#                                 "resize": "fit",
#                                 "w": 1200
#                             },
#                             "small": {
#                                 "h": 383,
#                                 "resize": "fit",
#                                 "w": 680
#                             },
#                             "thumb": {
#                                 "h": 150,
#                                 "resize": "crop",
#                                 "w": 150
#                             }
#                         },
#                         "source_status_id": 933835494777028608,
#                         "source_status_id_str": "933835494777028608",
#                         "source_user_id": 4112816181,
#                         "source_user_id_str": "4112816181",
#                         "type": "video",
#                         "url": "https://t.co/wOvzeCu1HI",
#                         "video_info": {
#                             "aspect_ratio": [
#                                 16,
#                                 9
#                             ],
#                             "duration_millis": 45012,
#                             "variants": [
#                                 {
#                                     "bitrate": 256000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/933834639495647233/pu/vid/320x180/n06rdLp19eQl4-hr.mp4"
#                                 },
#                                 {
#                                     "bitrate": 832000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/933834639495647233/pu/vid/640x360/BFsnPAuhPdmxqZ3H.mp4"
#                                 },
#                                 {
#                                     "content_type": "application/x-mpegURL",
#                                     "url": "https://video.twimg.com/ext_tw_video/933834639495647233/pu/pl/6FCbdF0F6YJQ6-Ju.m3u8"
#                                 },
#                                 {
#                                     "bitrate": 2176000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/933834639495647233/pu/vid/1280x720/5gF8BLQmhtVDFEib.mp4"
#                                 }
#                             ]
#                         }
#                     }
#                 ]
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 956698969597464576,
#             "id_str": "956698969597464576",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "is_quote_status": false,
#             "lang": "pt",
#             "metadata": {
#                 "iso_language_code": "pt",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "possibly_sensitive": false,
#             "retweet_count": 126,
#             "retweeted": false,
#             "retweeted_status": {
#                 "contributors": null,
#                 "coordinates": null,
#                 "created_at": "Tue Jan 23 21:27:09 +0000 2018",
#                 "entities": {
#                     "hashtags": [],
#                     "media": [
#                         {
#                             "display_url": "pic.twitter.com/wOvzeCu1HI",
#                             "expanded_url": "https://twitter.com/kcestrabao/status/933835494777028608/video/1",
#                             "id": 933834639495647233,
#                             "id_str": "933834639495647233",
#                             "indices": [
#                                 38,
#                                 61
#                             ],
#                             "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/933834639495647233/pu/img/lsyA0AAqKr4-JgPM.jpg",
#                             "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/933834639495647233/pu/img/lsyA0AAqKr4-JgPM.jpg",
#                             "sizes": {
#                                 "large": {
#                                     "h": 720,
#                                     "resize": "fit",
#                                     "w": 1280
#                                 },
#                                 "medium": {
#                                     "h": 675,
#                                     "resize": "fit",
#                                     "w": 1200
#                                 },
#                                 "small": {
#                                     "h": 383,
#                                     "resize": "fit",
#                                     "w": 680
#                                 },
#                                 "thumb": {
#                                     "h": 150,
#                                     "resize": "crop",
#                                     "w": 150
#                                 }
#                             },
#                             "source_status_id": 933835494777028608,
#                             "source_status_id_str": "933835494777028608",
#                             "source_user_id": 4112816181,
#                             "source_user_id_str": "4112816181",
#                             "type": "photo",
#                             "url": "https://t.co/wOvzeCu1HI"
#                         }
#                     ],
#                     "symbols": [],
#                     "urls": [],
#                     "user_mentions": []
#                 },
#                 "extended_entities": {
#                     "media": [
#                         {
#                             "additional_media_info": {
#                                 "monetizable": false
#                             },
#                             "display_url": "pic.twitter.com/wOvzeCu1HI",
#                             "expanded_url": "https://twitter.com/kcestrabao/status/933835494777028608/video/1",
#                             "id": 933834639495647233,
#                             "id_str": "933834639495647233",
#                             "indices": [
#                                 38,
#                                 61
#                             ],
#                             "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/933834639495647233/pu/img/lsyA0AAqKr4-JgPM.jpg",
#                             "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/933834639495647233/pu/img/lsyA0AAqKr4-JgPM.jpg",
#                             "sizes": {
#                                 "large": {
#                                     "h": 720,
#                                     "resize": "fit",
#                                     "w": 1280
#                                 },
#                                 "medium": {
#                                     "h": 675,
#                                     "resize": "fit",
#                                     "w": 1200
#                                 },
#                                 "small": {
#                                     "h": 383,
#                                     "resize": "fit",
#                                     "w": 680
#                                 },
#                                 "thumb": {
#                                     "h": 150,
#                                     "resize": "crop",
#                                     "w": 150
#                                 }
#                             },
#                             "source_status_id": 933835494777028608,
#                             "source_status_id_str": "933835494777028608",
#                             "source_user_id": 4112816181,
#                             "source_user_id_str": "4112816181",
#                             "type": "video",
#                             "url": "https://t.co/wOvzeCu1HI",
#                             "video_info": {
#                                 "aspect_ratio": [
#                                     16,
#                                     9
#                                 ],
#                                 "duration_millis": 45012,
#                                 "variants": [
#                                     {
#                                         "bitrate": 256000,
#                                         "content_type": "video/mp4",
#                                         "url": "https://video.twimg.com/ext_tw_video/933834639495647233/pu/vid/320x180/n06rdLp19eQl4-hr.mp4"
#                                     },
#                                     {
#                                         "bitrate": 832000,
#                                         "content_type": "video/mp4",
#                                         "url": "https://video.twimg.com/ext_tw_video/933834639495647233/pu/vid/640x360/BFsnPAuhPdmxqZ3H.mp4"
#                                     },
#                                     {
#                                         "content_type": "application/x-mpegURL",
#                                         "url": "https://video.twimg.com/ext_tw_video/933834639495647233/pu/pl/6FCbdF0F6YJQ6-Ju.m3u8"
#                                     },
#                                     {
#                                         "bitrate": 2176000,
#                                         "content_type": "video/mp4",
#                                         "url": "https://video.twimg.com/ext_tw_video/933834639495647233/pu/vid/1280x720/5gF8BLQmhtVDFEib.mp4"
#                                     }
#                                 ]
#                             }
#                         }
#                     ]
#                 },
#                 "favorite_count": 206,
#                 "favorited": false,
#                 "geo": null,
#                 "id": 955914828975104000,
#                 "id_str": "955914828975104000",
#                 "in_reply_to_screen_name": "rosescamilizers",
#                 "in_reply_to_status_id": 955896548071755776,
#                 "in_reply_to_status_id_str": "955896548071755776",
#                 "in_reply_to_user_id": 1430664355,
#                 "in_reply_to_user_id_str": "1430664355",
#                 "is_quote_status": false,
#                 "lang": "pt",
#                 "metadata": {
#                     "iso_language_code": "pt",
#                     "result_type": "recent"
#                 },
#                 "place": null,
#                 "possibly_sensitive": true,
#                 "retweet_count": 126,
#                 "retweeted": false,
#                 "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#                 "text": "tulla luana agradecendo a katy perry\n https://t.co/wOvzeCu1HI",
#                 "truncated": false,
#                 "user": {
#                     "contributors_enabled": false,
#                     "created_at": "Wed May 15 14:31:28 +0000 2013",
#                     "default_profile": false,
#                     "default_profile_image": false,
#                     "description": "me masturba com a tua l\u00edngua  @camiIathings",
#                     "entities": {
#                         "description": {
#                             "urls": []
#                         },
#                         "url": {
#                             "urls": [
#                                 {
#                                     "display_url": "curiouscat.me/rosescamilizer\u2026",
#                                     "expanded_url": "https://curiouscat.me/rosescamilizers?load",
#                                     "indices": [
#                                         0,
#                                         23
#                                     ],
#                                     "url": "https://t.co/vykCVptZxH"
#                                 }
#                             ]
#                         }
#                     },
#                     "favourites_count": 5789,
#                     "follow_request_sent": false,
#                     "followers_count": 39335,
#                     "following": false,
#                     "friends_count": 27108,
#                     "geo_enabled": true,
#                     "has_extended_profile": false,
#                     "id": 1430664355,
#                     "id_str": "1430664355",
#                     "is_translation_enabled": false,
#                     "is_translator": false,
#                     "lang": "pt",
#                     "listed_count": 542,
#                     "location": "",
#                     "name": "lara",
#                     "notifications": false,
#                     "profile_background_color": "FFCC4D",
#                     "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/599665044314460160/YXeFAich.jpg",
#                     "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/599665044314460160/YXeFAich.jpg",
#                     "profile_background_tile": true,
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/1430664355/1516857973",
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/956397352381796352/aI5zSlsU_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/956397352381796352/aI5zSlsU_normal.jpg",
#                     "profile_link_color": "F58EA8",
#                     "profile_sidebar_border_color": "000000",
#                     "profile_sidebar_fill_color": "DDEEF6",
#                     "profile_text_color": "333333",
#                     "profile_use_background_image": true,
#                     "protected": false,
#                     "screen_name": "rosescamilizers",
#                     "statuses_count": 258950,
#                     "time_zone": "Brasilia",
#                     "translator_type": "regular",
#                     "url": "https://t.co/vykCVptZxH",
#                     "utc_offset": -7200,
#                     "verified": false
#                 }
#             },
#             "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#             "text": "RT @rosescamilizers: tulla luana agradecendo a katy perry\n https://t.co/wOvzeCu1HI",
#             "truncated": false,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Sun Apr 23 22:32:32 +0000 2017",
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "description": "[nicky's voice]: hey, not-lesbians.",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "favourites_count": 3588,
#                 "follow_request_sent": false,
#                 "followers_count": 1524,
#                 "following": false,
#                 "friends_count": 1424,
#                 "geo_enabled": false,
#                 "has_extended_profile": false,
#                 "id": 856274616880427008,
#                 "id_str": "856274616880427008",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "pt",
#                 "listed_count": 2,
#                 "location": "seelie court",
#                 "name": "izzie",
#                 "notifications": false,
#                 "profile_background_color": "000000",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/856274616880427008/1516667609",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/955921607960203264/-rQ9T2Q-_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/955921607960203264/-rQ9T2Q-_normal.jpg",
#                 "profile_link_color": "E81C4F",
#                 "profile_sidebar_border_color": "000000",
#                 "profile_sidebar_fill_color": "000000",
#                 "profile_text_color": "000000",
#                 "profile_use_background_image": false,
#                 "protected": false,
#                 "screen_name": "wwnderful",
#                 "statuses_count": 6521,
#                 "time_zone": null,
#                 "translator_type": "none",
#                 "url": null,
#                 "utc_offset": null,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Fri Jan 26 01:22:50 +0000 2018",
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "urls": [],
#                 "user_mentions": [
#                     {
#                         "id": 2484226796,
#                         "id_str": "2484226796",
#                         "indices": [
#                             3,
#                             14
#                         ],
#                         "name": "PEDRAO",
#                         "screen_name": "Itspedrito"
#                     }
#                 ]
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 956698915457372165,
#             "id_str": "956698915457372165",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "is_quote_status": false,
#             "lang": "pt",
#             "metadata": {
#                 "iso_language_code": "pt",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "retweet_count": 49,
#             "retweeted": false,
#             "retweeted_status": {
#                 "contributors": null,
#                 "coordinates": null,
#                 "created_at": "Fri Jan 26 00:21:23 +0000 2018",
#                 "entities": {
#                     "hashtags": [],
#                     "symbols": [],
#                     "urls": [],
#                     "user_mentions": []
#                 },
#                 "favorite_count": 109,
#                 "favorited": false,
#                 "geo": null,
#                 "id": 956683449607360514,
#                 "id_str": "956683449607360514",
#                 "in_reply_to_screen_name": null,
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "is_quote_status": false,
#                 "lang": "pt",
#                 "metadata": {
#                     "iso_language_code": "pt",
#                     "result_type": "recent"
#                 },
#                 "place": null,
#                 "retweet_count": 49,
#                 "retweeted": false,
#                 "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#                 "text": "manda mimos\n\nde preferencia ingresso pro show da katy perry",
#                 "truncated": false,
#                 "user": {
#                     "contributors_enabled": false,
#                     "created_at": "Thu May 08 17:13:09 +0000 2014",
#                     "default_profile": false,
#                     "default_profile_image": false,
#                     "description": "Interesses publicit\u00e1rios: oitspedrito@gmail.com \u2709",
#                     "entities": {
#                         "description": {
#                             "urls": []
#                         },
#                         "url": {
#                             "urls": [
#                                 {
#                                     "display_url": "facebook.com/oitspedrito",
#                                     "expanded_url": "http://facebook.com/oitspedrito",
#                                     "indices": [
#                                         0,
#                                         23
#                                     ],
#                                     "url": "https://t.co/ZWCPyXQiNo"
#                                 }
#                             ]
#                         }
#                     },
#                     "favourites_count": 23657,
#                     "follow_request_sent": false,
#                     "followers_count": 831905,
#                     "following": false,
#                     "friends_count": 706,
#                     "geo_enabled": false,
#                     "has_extended_profile": true,
#                     "id": 2484226796,
#                     "id_str": "2484226796",
#                     "is_translation_enabled": false,
#                     "is_translator": false,
#                     "lang": "pt",
#                     "listed_count": 3044,
#                     "location": "Brasil",
#                     "name": "PEDRAO",
#                     "notifications": false,
#                     "profile_background_color": "000000",
#                     "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/624324854657888256/sRDjKVXZ.png",
#                     "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/624324854657888256/sRDjKVXZ.png",
#                     "profile_background_tile": true,
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/2484226796/1460853119",
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/813590868066271233/U-1LgGbb_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/813590868066271233/U-1LgGbb_normal.jpg",
#                     "profile_link_color": "000000",
#                     "profile_sidebar_border_color": "000000",
#                     "profile_sidebar_fill_color": "000000",
#                     "profile_text_color": "000000",
#                     "profile_use_background_image": true,
#                     "protected": false,
#                     "screen_name": "Itspedrito",
#                     "statuses_count": 110455,
#                     "time_zone": "Mid-Atlantic",
#                     "translator_type": "regular",
#                     "url": "https://t.co/ZWCPyXQiNo",
#                     "utc_offset": -7200,
#                     "verified": false
#                 }
#             },
#             "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#             "text": "RT @Itspedrito: manda mimos\n\nde preferencia ingresso pro show da katy perry",
#             "truncated": false,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Tue Jul 09 03:22:56 +0000 2013",
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "description": "da uma bolachinha?",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "favourites_count": 12255,
#                 "follow_request_sent": false,
#                 "followers_count": 10141,
#                 "following": false,
#                 "friends_count": 4111,
#                 "geo_enabled": true,
#                 "has_extended_profile": true,
#                 "id": 1579316851,
#                 "id_str": "1579316851",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "pt",
#                 "listed_count": 11,
#                 "location": "hogwarts ",
#                 "name": "thay",
#                 "notifications": false,
#                 "profile_background_color": "FFFFFF",
#                 "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/565182428528902144/q1-Fn9A_.jpeg",
#                 "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/565182428528902144/q1-Fn9A_.jpeg",
#                 "profile_background_tile": true,
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/1579316851/1515800179",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/951961049170939904/aXC_8-zF_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/951961049170939904/aXC_8-zF_normal.jpg",
#                 "profile_link_color": "E81C4F",
#                 "profile_sidebar_border_color": "000000",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": false,
#                 "protected": false,
#                 "screen_name": "wtftomlinsons",
#                 "statuses_count": 66046,
#                 "time_zone": "Brasilia",
#                 "translator_type": "none",
#                 "url": null,
#                 "utc_offset": -7200,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Fri Jan 26 01:22:37 +0000 2018",
#             "entities": {
#                 "hashtags": [
#                     {
#                         "indices": [
#                             110,
#                             120
#                         ],
#                         "text": "tothemoon"
#                     }
#                 ],
#                 "symbols": [],
#                 "urls": [],
#                 "user_mentions": [
#                     {
#                         "id": 287452368,
#                         "id_str": "287452368",
#                         "indices": [
#                             3,
#                             16
#                         ],
#                         "name": "Vanessa Mota",
#                         "screen_name": "vaanessamota"
#                     }
#                 ]
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 956698861128515584,
#             "id_str": "956698861128515584",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "is_quote_status": false,
#             "lang": "pt",
#             "metadata": {
#                 "iso_language_code": "pt",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "retweet_count": 1,
#             "retweeted": false,
#             "retweeted_status": {
#                 "contributors": null,
#                 "coordinates": null,
#                 "created_at": "Fri Jan 26 00:46:55 +0000 2018",
#                 "entities": {
#                     "hashtags": [
#                         {
#                             "indices": [
#                                 92,
#                                 102
#                             ],
#                             "text": "tothemoon"
#                         }
#                     ],
#                     "symbols": [],
#                     "urls": [
#                         {
#                             "display_url": "twitter.com/i/web/status/9\u2026",
#                             "expanded_url": "https://twitter.com/i/web/status/956689877285916672",
#                             "indices": [
#                                 117,
#                                 140
#                             ],
#                             "url": "https://t.co/CZ3s682eVG"
#                         }
#                     ],
#                     "user_mentions": []
#                 },
#                 "favorite_count": 2,
#                 "favorited": false,
#                 "geo": null,
#                 "id": 956689877285916672,
#                 "id_str": "956689877285916672",
#                 "in_reply_to_screen_name": null,
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "is_quote_status": false,
#                 "lang": "pt",
#                 "metadata": {
#                     "iso_language_code": "pt",
#                     "result_type": "recent"
#                 },
#                 "place": null,
#                 "retweet_count": 1,
#                 "retweeted": false,
#                 "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#                 "text": "Katy Perry pintou as unhas com s\u00edmbolos de criptomoedas por cima do d\u00f3lar e com foguetinhos #tothemoon. \n\nque fique\u2026 https://t.co/CZ3s682eVG",
#                 "truncated": true,
#                 "user": {
#                     "contributors_enabled": false,
#                     "created_at": "Mon Apr 25 01:15:32 +0000 2011",
#                     "default_profile": false,
#                     "default_profile_image": false,
#                     "description": "Mostly tech and sports. \nPSG & Sampaio. Crypto-Anarchist",
#                     "entities": {
#                         "description": {
#                             "urls": []
#                         }
#                     },
#                     "favourites_count": 7555,
#                     "follow_request_sent": false,
#                     "followers_count": 286,
#                     "following": false,
#                     "friends_count": 592,
#                     "geo_enabled": true,
#                     "has_extended_profile": false,
#                     "id": 287452368,
#                     "id_str": "287452368",
#                     "is_translation_enabled": false,
#                     "is_translator": false,
#                     "lang": "pt",
#                     "listed_count": 4,
#                     "location": "Ancapist\u00e3o",
#                     "name": "Vanessa Mota",
#                     "notifications": false,
#                     "profile_background_color": "C0DEED",
#                     "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/609897195/ghavp3beo33pzmt2n1a2.jpeg",
#                     "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/609897195/ghavp3beo33pzmt2n1a2.jpeg",
#                     "profile_background_tile": true,
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/287452368/1512688484",
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/813222999428108289/MJB9Vras_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/813222999428108289/MJB9Vras_normal.jpg",
#                     "profile_link_color": "0084B4",
#                     "profile_sidebar_border_color": "C0DEED",
#                     "profile_sidebar_fill_color": "DDEEF6",
#                     "profile_text_color": "333333",
#                     "profile_use_background_image": true,
#                     "protected": false,
#                     "screen_name": "vaanessamota",
#                     "statuses_count": 5340,
#                     "time_zone": "Brasilia",
#                     "translator_type": "none",
#                     "url": null,
#                     "utc_offset": -7200,
#                     "verified": false
#                 }
#             },
#             "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#             "text": "RT @vaanessamota: Katy Perry pintou as unhas com s\u00edmbolos de criptomoedas por cima do d\u00f3lar e com foguetinhos #tothemoon. \n\nque fique bem c\u2026",
#             "truncated": false,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Sat Aug 06 15:44:27 +0000 2016",
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "description": "eu quero ver o oco",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "favourites_count": 9332,
#                 "follow_request_sent": false,
#                 "followers_count": 186,
#                 "following": false,
#                 "friends_count": 113,
#                 "geo_enabled": false,
#                 "has_extended_profile": true,
#                 "id": 761951076681678849,
#                 "id_str": "761951076681678849",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "pt",
#                 "listed_count": 2,
#                 "location": "S\u00e3o Lu\u00eds, Brasil",
#                 "name": "net\u00f8 \u23fa\ufe0f",
#                 "notifications": false,
#                 "profile_background_color": "000000",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/761951076681678849/1516569145",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/953941602837389312/6tbkiSuX_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/953941602837389312/6tbkiSuX_normal.jpg",
#                 "profile_link_color": "313131",
#                 "profile_sidebar_border_color": "000000",
#                 "profile_sidebar_fill_color": "000000",
#                 "profile_text_color": "000000",
#                 "profile_use_background_image": false,
#                 "protected": false,
#                 "screen_name": "oinconquistado",
#                 "statuses_count": 7239,
#                 "time_zone": "Pacific Time (US & Canada)",
#                 "translator_type": "none",
#                 "url": null,
#                 "utc_offset": -28800,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Fri Jan 26 01:22:27 +0000 2018",
#             "entities": {
#                 "hashtags": [
#                     {
#                         "indices": [
#                             21,
#                             31
#                         ],
#                         "text": "KPNVideos"
#                     }
#                 ],
#                 "symbols": [],
#                 "urls": [],
#                 "user_mentions": [
#                     {
#                         "id": 79821768,
#                         "id_str": "79821768",
#                         "indices": [
#                             3,
#                             19
#                         ],
#                         "name": "Katy Perry Notice",
#                         "screen_name": "katyperrynotice"
#                     }
#                 ]
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 956698818606784515,
#             "id_str": "956698818606784515",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "is_quote_status": false,
#             "lang": "pt",
#             "metadata": {
#                 "iso_language_code": "pt",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "retweet_count": 6,
#             "retweeted": false,
#             "retweeted_status": {
#                 "contributors": null,
#                 "coordinates": null,
#                 "created_at": "Thu Jan 25 21:54:09 +0000 2018",
#                 "entities": {
#                     "hashtags": [
#                         {
#                             "indices": [
#                                 0,
#                                 10
#                             ],
#                             "text": "KPNVideos"
#                         }
#                     ],
#                     "media": [
#                         {
#                             "display_url": "pic.twitter.com/eh6sazyLqH",
#                             "expanded_url": "https://twitter.com/katyperrynotice/status/956646395628457984/video/1",
#                             "id": 956645646580244481,
#                             "id_str": "956645646580244481",
#                             "indices": [
#                                 110,
#                                 133
#                             ],
#                             "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/956645646580244481/pu/img/NNmtalCqVMsQXYJv.jpg",
#                             "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/956645646580244481/pu/img/NNmtalCqVMsQXYJv.jpg",
#                             "sizes": {
#                                 "large": {
#                                     "h": 1136,
#                                     "resize": "fit",
#                                     "w": 640
#                                 },
#                                 "medium": {
#                                     "h": 1136,
#                                     "resize": "fit",
#                                     "w": 640
#                                 },
#                                 "small": {
#                                     "h": 680,
#                                     "resize": "fit",
#                                     "w": 383
#                                 },
#                                 "thumb": {
#                                     "h": 150,
#                                     "resize": "crop",
#                                     "w": 150
#                                 }
#                             },
#                             "type": "photo",
#                             "url": "https://t.co/eh6sazyLqH"
#                         }
#                     ],
#                     "symbols": [],
#                     "urls": [],
#                     "user_mentions": []
#                 },
#                 "extended_entities": {
#                     "media": [
#                         {
#                             "additional_media_info": {
#                                 "monetizable": false
#                             },
#                             "display_url": "pic.twitter.com/eh6sazyLqH",
#                             "expanded_url": "https://twitter.com/katyperrynotice/status/956646395628457984/video/1",
#                             "id": 956645646580244481,
#                             "id_str": "956645646580244481",
#                             "indices": [
#                                 110,
#                                 133
#                             ],
#                             "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/956645646580244481/pu/img/NNmtalCqVMsQXYJv.jpg",
#                             "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/956645646580244481/pu/img/NNmtalCqVMsQXYJv.jpg",
#                             "sizes": {
#                                 "large": {
#                                     "h": 1136,
#                                     "resize": "fit",
#                                     "w": 640
#                                 },
#                                 "medium": {
#                                     "h": 1136,
#                                     "resize": "fit",
#                                     "w": 640
#                                 },
#                                 "small": {
#                                     "h": 680,
#                                     "resize": "fit",
#                                     "w": 383
#                                 },
#                                 "thumb": {
#                                     "h": 150,
#                                     "resize": "crop",
#                                     "w": 150
#                                 }
#                             },
#                             "type": "video",
#                             "url": "https://t.co/eh6sazyLqH",
#                             "video_info": {
#                                 "aspect_ratio": [
#                                     40,
#                                     71
#                                 ],
#                                 "duration_millis": 40871,
#                                 "variants": [
#                                     {
#                                         "bitrate": 832000,
#                                         "content_type": "video/mp4",
#                                         "url": "https://video.twimg.com/ext_tw_video/956645646580244481/pu/vid/360x640/PKoFW3a_Pc6bksmh.mp4"
#                                     },
#                                     {
#                                         "content_type": "application/x-mpegURL",
#                                         "url": "https://video.twimg.com/ext_tw_video/956645646580244481/pu/pl/6UH8rrA603ks8M87.m3u8"
#                                     },
#                                     {
#                                         "bitrate": 256000,
#                                         "content_type": "video/mp4",
#                                         "url": "https://video.twimg.com/ext_tw_video/956645646580244481/pu/vid/180x320/YMtYLicgPropXY9-.mp4"
#                                     }
#                                 ]
#                             }
#                         }
#                     ]
#                 },
#                 "favorite_count": 8,
#                 "favorited": false,
#                 "geo": null,
#                 "id": 956646395628457984,
#                 "id_str": "956646395628457984",
#                 "in_reply_to_screen_name": null,
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "is_quote_status": false,
#                 "lang": "pt",
#                 "metadata": {
#                     "iso_language_code": "pt",
#                     "result_type": "recent"
#                 },
#                 "place": null,
#                 "possibly_sensitive": false,
#                 "retweet_count": 6,
#                 "retweeted": false,
#                 "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#                 "text": "#KPNVideos | Katy Perry, Lionel Richie e Luke Bryan em mais um dia de grava\u00e7\u00f5es do American Idol em Hollywood https://t.co/eh6sazyLqH",
#                 "truncated": false,
#                 "user": {
#                     "contributors_enabled": false,
#                     "created_at": "Sun Oct 04 20:24:32 +0000 2009",
#                     "default_profile": false,
#                     "default_profile_image": false,
#                     "description": "Sua melhor fonte sobre a cantora Katy Perry.",
#                     "entities": {
#                         "description": {
#                             "urls": []
#                         },
#                         "url": {
#                             "urls": [
#                                 {
#                                     "display_url": "instagram.com/katyperrynotic\u2026",
# ...
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     },
#                     "url": {
#                         "urls": [
#                             {
#                                 "display_url": "instagram.com/cantapramimlr",
#                                 "expanded_url": "https://instagram.com/cantapramimlr",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ],
#                                 "url": "https://t.co/PHSxsfjUlG"
#                             }
#                         ]
#                     }
#                 },
#                 "favourites_count": 5959,
#                 "follow_request_sent": false,
#                 "followers_count": 2687,
#                 "following": false,
#                 "friends_count": 2339,
#                 "geo_enabled": true,
#                 "has_extended_profile": true,
#                 "id": 1633136412,
#                 "id_str": "1633136412",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "pt",
#                 "listed_count": 5,
#                 "location": "Pinhais ",
#                 "name": "Thaynara",
#                 "notifications": false,
#                 "profile_background_color": "FCFCFC",
#                 "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/440018409032392704/oHyClPEZ.png",
#                 "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/440018409032392704/oHyClPEZ.png",
#                 "profile_background_tile": true,
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/1633136412/1496815113",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/935738473092403200/_X6N-dp5_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/935738473092403200/_X6N-dp5_normal.jpg",
#                 "profile_link_color": "ABB8C2",
#                 "profile_sidebar_border_color": "FFFFFF",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": false,
#                 "protected": false,
#                 "screen_name": "cantapramimlr",
#                 "statuses_count": 42346,
#                 "time_zone": "Brasilia",
#                 "translator_type": "none",
#                 "url": "https://t.co/PHSxsfjUlG",
#                 "utc_offset": -7200,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Fri Jan 26 01:10:08 +0000 2018",
#             "entities": {
#                 "hashtags": [
#                     {
#                         "indices": [
#                             66,
#                             76
#                         ],
#                         "text": "KatyPerry"
#                     }
#                 ],
#                 "symbols": [],
#                 "urls": [
#                     {
#                         "display_url": "youtu.be/hdw1uKiTI5c",
#                         "expanded_url": "https://youtu.be/hdw1uKiTI5c",
#                         "indices": [
#                             29,
#                             52
#                         ],
#                         "url": "https://t.co/kxjNJ5bEbk"
#                     }
#                 ],
#                 "user_mentions": [
#                     {
#                         "id": 10228272,
#                         "id_str": "10228272",
#                         "indices": [
#                             57,
#                             65
#                         ],
#                         "name": "YouTube",
#                         "screen_name": "YouTube"
#                     }
#                 ]
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 956695716474257410,
#             "id_str": "956695716474257410",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "is_quote_status": false,
#             "lang": "en",
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "possibly_sensitive": false,
#             "retweet_count": 0,
#             "retweeted": false,
#             "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#             "text": "Katy Perry - Rise (Official) https://t.co/kxjNJ5bEbk via @YouTube #KatyPerry",
#             "truncated": false,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Sat Apr 12 15:24:54 +0000 2014",
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "description": "",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "favourites_count": 20424,
#                 "follow_request_sent": false,
#                 "followers_count": 144,
#                 "following": false,
#                 "friends_count": 221,
#                 "geo_enabled": true,
#                 "has_extended_profile": true,
#                 "id": 2440158972,
#                 "id_str": "2440158972",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "de",
#                 "listed_count": 47,
#                 "location": "Germany",
#                 "name": "Andreas Hahn",
#                 "notifications": false,
#                 "profile_background_color": "000000",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/2440158972/1398863956",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/455017863955222529/54cZOGVR_normal.jpeg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/455017863955222529/54cZOGVR_normal.jpeg",
#                 "profile_link_color": "1B95E0",
#                 "profile_sidebar_border_color": "000000",
#                 "profile_sidebar_fill_color": "000000",
#                 "profile_text_color": "000000",
#                 "profile_use_background_image": false,
#                 "protected": false,
#                 "screen_name": "andyhof",
#                 "statuses_count": 25753,
#                 "time_zone": "Bern",
#                 "translator_type": "none",
#                 "url": null,
#                 "utc_offset": 3600,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Fri Jan 26 01:10:06 +0000 2018",
#             "entities": {
#                 "hashtags": [],
#                 "media": [
#                     {
#                         "display_url": "pic.twitter.com/kxtJ6Izit4",
#                         "expanded_url": "https://twitter.com/Andreadavis221/status/869792250116681729/video/1",
#                         "id": 869792197171965953,
#                         "id_str": "869792197171965953",
#                         "indices": [
#                             37,
#                             60
#                         ],
#                         "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/869792197171965953/pu/img/pcrGQfoSakmz-6E-.jpg",
#                         "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/869792197171965953/pu/img/pcrGQfoSakmz-6E-.jpg",
#                         "sizes": {
#                             "large": {
#                                 "h": 480,
#                                 "resize": "fit",
#                                 "w": 640
#                             },
#                             "medium": {
#                                 "h": 480,
#                                 "resize": "fit",
#                                 "w": 640
#                             },
#                             "small": {
#                                 "h": 480,
#                                 "resize": "fit",
#                                 "w": 640
#                             },
#                             "thumb": {
#                                 "h": 150,
#                                 "resize": "crop",
#                                 "w": 150
#                             }
#                         },
#                         "source_status_id": 869792250116681729,
#                         "source_status_id_str": "869792250116681729",
#                         "source_user_id": 860199528326062080,
#                         "source_user_id_str": "860199528326062080",
#                         "type": "photo",
#                         "url": "https://t.co/kxtJ6Izit4"
#                     }
#                 ],
#                 "symbols": [],
#                 "urls": [],
#                 "user_mentions": []
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "additional_media_info": {
#                             "monetizable": false
#                         },
#                         "display_url": "pic.twitter.com/kxtJ6Izit4",
#                         "expanded_url": "https://twitter.com/Andreadavis221/status/869792250116681729/video/1",
#                         "id": 869792197171965953,
#                         "id_str": "869792197171965953",
#                         "indices": [
#                             37,
#                             60
#                         ],
#                         "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/869792197171965953/pu/img/pcrGQfoSakmz-6E-.jpg",
#                         "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/869792197171965953/pu/img/pcrGQfoSakmz-6E-.jpg",
#                         "sizes": {
#                             "large": {
#                                 "h": 480,
#                                 "resize": "fit",
#                                 "w": 640
#                             },
#                             "medium": {
#                                 "h": 480,
#                                 "resize": "fit",
#                                 "w": 640
#                             },
#                             "small": {
#                                 "h": 480,
#                                 "resize": "fit",
#                                 "w": 640
#                             },
#                             "thumb": {
#                                 "h": 150,
#                                 "resize": "crop",
#                                 "w": 150
#                             }
#                         },
#                         "source_status_id": 869792250116681729,
#                         "source_status_id_str": "869792250116681729",
#                         "source_user_id": 860199528326062080,
#                         "source_user_id_str": "860199528326062080",
#                         "type": "video",
#                         "url": "https://t.co/kxtJ6Izit4",
#                         "video_info": {
#                             "aspect_ratio": [
#                                 4,
#                                 3
#                             ],
#                             "duration_millis": 10360,
#                             "variants": [
#                                 {
#                                     "content_type": "application/x-mpegURL",
#                                     "url": "https://video.twimg.com/ext_tw_video/869792197171965953/pu/pl/dal9_Ld8LjghnVhZ.m3u8"
#                                 },
#                                 {
#                                     "bitrate": 256000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/869792197171965953/pu/vid/240x180/nPjvQUTIwaWtFLyh.mp4"
#                                 },
#                                 {
#                                     "bitrate": 832000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/869792197171965953/pu/vid/480x360/QtHMX4BAja9NY_9-.mp4"
#                                 }
#                             ]
#                         }
#                     }
#                 ]
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 956695712003186688,
#             "id_str": "956695712003186688",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "is_quote_status": false,
#             "lang": "en",
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "possibly_sensitive": false,
#             "retweet_count": 0,
#             "retweeted": false,
#             "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#             "text": "naked katy perry pics anal play pics https://t.co/kxtJ6Izit4",
#             "truncated": false,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Sun Sep 23 06:43:50 +0000 2012",
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "description": "",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "favourites_count": 0,
#                 "follow_request_sent": false,
#                 "followers_count": 26,
#                 "following": false,
#                 "friends_count": 7,
#                 "geo_enabled": false,
#                 "has_extended_profile": false,
#                 "id": 841161061,
#                 "id_str": "841161061",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "en",
#                 "listed_count": 0,
#                 "location": "",
#                 "name": "Alexandra Cox",
#                 "notifications": false,
#                 "profile_background_color": "C0DEED",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/949173414085918720/ctD0MvxU_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/949173414085918720/ctD0MvxU_normal.jpg",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "protected": false,
#                 "screen_name": "marklisec",
#                 "statuses_count": 6739,
#                 "time_zone": null,
#                 "translator_type": "none",
#                 "url": null,
#                 "utc_offset": null,
#                 "verified": false
#             }
#         }
#     ]
# }

# %%
# "Real Person" Filters
min_tweets = 5
max_tweets = 10000
max_followers = 2500
max_following = 2500
lang = "en"

# Array of Eligible Tweets
tweet_array = []

# %%
# Print Tweets
for tweet in public_tweets["statuses"]:
    # Use filters to check if user meets conditions
    if (tweet["user"]["followers_count"] < max_followers and
        tweet["user"]["statuses_count"] > min_tweets and
        tweet["user"]["statuses_count"] < max_tweets and
        tweet["user"]["friends_count"] < max_following and
            tweet["user"]["lang"] == lang
       ):

        # If so add the user's tweet to the array (for future use)
        tweet_array.append(tweet["text"])

        # Print the username
        print(tweet["user"]["screen_name"])

        # Print the tweet text
        print(tweet["text"])
        print("")

# Print total number of tweets
print(len(tweet_array))
# Out:
# mortaelinda
# RT @katyperrynotice: #KPNVideos | Katy Perry, Lionel Richie e Luke Bryan em mais um dia de gravações do American Idol em Hollywood https://…
#
# jamesmceldowney
# RT @karol: It's happening. My 7yo is moving from loving Bob Dylan and the Beatles to Katy Perry and Miley Cyrus. https://t.co/tl1h7lP6JX
#
# y101tweets
# We're glad Katy is safe! This could have ended much worse! 😲 https://t.co/HhaXDZPVxN
#
# MarkFuselier1
# News of tomorrow "Breaking news, Bitcoin value tanks as story about Katy Perry's nails breaks" https://t.co/NkaP5BAGTS
#
# lurksquahh
# RT @ChiefKeef: Dat bitch Katy Perry Can Suck Skin Off Of my Dick
#
# FabergeDoll
# RT @TMZ: Katy Perry Obsessed Fan Found Guilty of Stalking, Gets Deported https://t.co/yemUZ4HhyE
#
# ponchogonz30
# RT @VantablackSSB: Hot take: Katy Perry was never good
#
# hervedestin
# RT @CryptoBoomNews: You know #cryptocurrency has gone mainstream when Katy Perry has #crypto themed fingernails. #BTC #LTC #XLM #XMR #TRX h…
#
# AmandaGiardullo
# RT @PopCrave: Katy Perry introduces Minnie Mouse into the Hollywood Walk of Fame and throws a bit of shade at Hollywood for giving Minnie M…
#
# JKoshin21
# RT @NeerajKA: Katy Perry has cryptocurrency nails now https://t.co/DY4d2uKbub
#
# (h/t @nondualnelly ) https://t.co/nhnw95onfo
#
# davtor98
# RT @iMusicPolls: Artist Battle: Taylor Swift vs. Katy Perry
#
# LIKE — Katy Perry
# RETWEET — Taylor Swift https://t.co/aeNhd913kJ
#
# FabergeDoll
# RT @katyspics: "[Katy] found a way to personally connect with every contestant that she critiqued, whether it be complimenting their outfit…
#
# smrulinda
# RT @lilysgross: [exuberantly sung to the tune of Katy Perry’s “Firework”] DO YOU EVER FEEL, LIKE A PIECE OF SHIT
#
# Smackoff24Champ
# @TMZ Why deported? I thought liberal Katy perry was against deportations
#
# kysdaryel
# i bet katy perry mines bitcoin
#
# vikasagar1
# gaara fucking katy perry fake nude pic https://t.co/RCNg4IcEJt
#
# TheWanderRerr
# RT @CryptoEye111: 50 Cent, Katy Perry, I'm beginning to see a trend here...
# $crypto
#
# dhanai
# RT @MarketWatch: 5 cryptos to keep an eye on this year, according to Katy Perry’s fingernails https://t.co/fTV7pwHMgd
#
# ortiz_adrinana
# RT @CryptoEye111: It's awesome to have been included in Twitter's Katy Perry moment related to $crypto.
#
#  ⚡️ “Katy Perry is showing off her…
#
# bryaninbigd
# @junior_miller @CashSports @katyperry Remember when Katy Perry was really cute, with a killer body, catchy pop tune… https://t.co/d9OSwTOpme
#
# marklisec
# naked katy perry pics anal play pics https://t.co/kxtJ6Izit4
#
# 21
