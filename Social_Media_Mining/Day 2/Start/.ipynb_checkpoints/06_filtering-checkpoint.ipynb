# %%
import json
import tweepy 
import os

# %%
api_dir = os.path.dirname(os.path.dirname(os.path.dirname(os.path.dirname(os.path.dirname(os.path.realpath('__file__'))))))
file_name = os.path.join(api_dir, "api_keys.json")
data = json.load(open(file_name))

consumer_key = data['twitter_consumer_key']
consumer_secret = data['twitter_consumer_secret']
access_token = data['twitter_access_token']
access_token_secret = data['twitter_access_token_secret']

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Search for People Tweeting about Katy Perry
search_term = "Katy Perry"


# Retrieve 100 tweets
public_tweets = api.search(search_term, count=100)

# %%
#public_tweets['statuses'][0]
print(json.dumps(public_tweets, sort_keys=True, indent=4, separators=(',', ': ')))
# Out:
# {
#     "search_metadata": {
#         "completed_in": 0.08,
#         "count": 100,
#         "max_id": 952971612122427392,
#         "max_id_str": "952971612122427392",
#         "next_results": "?max_id=952968186294566913&q=Katy%20Perry&count=100&include_entities=1",
#         "query": "Katy+Perry",
#         "refresh_url": "?since_id=952971612122427392&q=Katy%20Perry&include_entities=1",
#         "since_id": 0,
#         "since_id_str": "0"
#     },
#     "statuses": [
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Mon Jan 15 18:31:52 +0000 2018",
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "urls": [
#                     {
#                         "display_url": "twitter.com/i/web/status/9\u2026",
#                         "expanded_url": "https://twitter.com/i/web/status/952971612122427392",
#                         "indices": [
#                             117,
#                             140
#                         ],
#                         "url": "https://t.co/MomyS2VKRC"
#                     }
#                 ],
#                 "user_mentions": []
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 952971612122427392,
#             "id_str": "952971612122427392",
#             "in_reply_to_screen_name": "AngelM98",
#             "in_reply_to_status_id": 952648771741110272,
#             "in_reply_to_status_id_str": "952648771741110272",
#             "in_reply_to_user_id": 2358353916,
#             "in_reply_to_user_id_str": "2358353916",
#             "is_quote_status": false,
#             "lang": "ru",
#             "metadata": {
#                 "iso_language_code": "ru",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "retweet_count": 0,
#             "retweeted": false,
#             "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#             "text": "Day 15. \u041f\u0435\u0441\u043d\u044f-\u043a\u0430\u0432\u0435\u0440, \u043a\u043e\u0442\u043e\u0440\u0430\u044f \u0432\u0430\u043c \u043d\u0440\u0430\u0432\u0438\u0442\u0441\u044f\nOur Last Night - Dark Horse (Katy Perry cover)\n\u0418\u043c\u0435\u043d\u043d\u043e \u0441 \u044d\u0442\u043e\u0433\u043e \u043a\u0430\u0432\u0435\u0440\u0430 \u0438 \u043d\u0430\u2026 https://t.co/MomyS2VKRC",
#             "truncated": true,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Sun Feb 23 18:37:46 +0000 2014",
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "description": "\u041a\u0438\u0434\u0430\u044e \u0432\u044b\u0437\u043e\u0432 \u043c\u0438\u0440\u0443...\u043f\u043e\u0434 \u043e\u0442\u043b\u0438\u0447\u043d\u0443\u044e \u043c\u0443\u0437\u044b\u043a\u0443:\u0417\nOpen up my mind\n\u041a\u043d\u0438\u0436\u043d\u044b\u0439 \u0447\u0435\u0440\u0432\u044c\n#FOB#GD#30stM#\u041c\u0435\u043b\u044c\u043d\u0438\u0446\u0430#T\u00d8P\ntear in my heart  - @nemka57\n\u2661\u2661\u2661- @lookatcoda",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "favourites_count": 22633,
#                 "follow_request_sent": false,
#                 "followers_count": 1032,
#                 "following": false,
#                 "friends_count": 1314,
#                 "geo_enabled": true,
#                 "has_extended_profile": true,
#                 "id": 2358353916,
#                 "id_str": "2358353916",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "ru",
#                 "listed_count": 3,
#                 "location": "Death Valley ",
#                 "name": "\u2615Royal Milk Tea\u2615",
#                 "notifications": false,
#                 "profile_background_color": "C0DEED",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/2358353916/1510494155",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/929705694298886144/9M5rkvhX_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/929705694298886144/9M5rkvhX_normal.jpg",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "protected": false,
#                 "screen_name": "AngelM98",
#                 "statuses_count": 15845,
#                 "time_zone": null,
#                 "translator_type": "none",
#                 "url": null,
#                 "utc_offset": null,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Mon Jan 15 18:31:47 +0000 2018",
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "urls": [],
#                 "user_mentions": [
#                     {
#                         "id": 867479700020621314,
#                         "id_str": "867479700020621314",
#                         "indices": [
#                             3,
#                             12
#                         ],
#                         "name": "\u2728BTS SQUAD\u2728",
#                         "screen_name": "Bitiiez_"
#                     }
#                 ]
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 952971591230554113,
#             "id_str": "952971591230554113",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "is_quote_status": false,
#             "lang": "es",
#             "metadata": {
#                 "iso_language_code": "es",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "retweet_count": 1808,
#             "retweeted": false,
#             "retweeted_status": {
#                 "contributors": null,
#                 "coordinates": null,
#                 "created_at": "Mon Jan 15 03:30:02 +0000 2018",
#                 "entities": {
#                     "hashtags": [],
#                     "symbols": [],
#                     "urls": [
#                         {
#                             "display_url": "twitter.com/i/web/status/9\u2026",
#                             "expanded_url": "https://twitter.com/i/web/status/952744660425953280",
#                             "indices": [
#                                 117,
#                                 140
#                             ],
#                             "url": "https://t.co/4sAHBNPRlr"
#                         }
#                     ],
#                     "user_mentions": []
#                 },
#                 "favorite_count": 2146,
#                 "favorited": false,
#                 "geo": null,
#                 "id": 952744660425953280,
#                 "id_str": "952744660425953280",
#                 "in_reply_to_screen_name": null,
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "is_quote_status": false,
#                 "lang": "es",
#                 "metadata": {
#                     "iso_language_code": "es",
#                     "result_type": "recent"
#                 },
#                 "place": null,
#                 "possibly_sensitive": false,
#                 "retweet_count": 1808,
#                 "retweeted": false,
#                 "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#                 "text": "Por alguna raz\u00f3n... me hacen acordar a estas otras \ud83d\udcf7\nTaehyung \u27a1\ufe0f Pollito Enojado\nJimin \u27a1\ufe0f a los tiburones(bailarine\u2026 https://t.co/4sAHBNPRlr",
#                 "truncated": true,
#                 "user": {
#                     "contributors_enabled": false,
#                     "created_at": "Wed May 24 20:37:32 +0000 2017",
#                     "default_profile": false,
#                     "default_profile_image": false,
#                     "description": "Segunda cuenta de apoyo.\nNos suspendieron tres veces nuestra cuenta original @bitiiez as\u00ed que mantendremos abierta esta por las dudas. \u00a1Gracias por el apoyo! \u2665",
#                     "entities": {
#                         "description": {
#                             "urls": []
#                         },
#                         "url": {
#                             "urls": [
#                                 {
#                                     "display_url": "youtube.com/channel/UClpLO\u2026",
#                                     "expanded_url": "http://www.youtube.com/channel/UClpLO4zWdSXxYN5x5lon5Fw",
#                                     "indices": [
#                                         0,
#                                         23
#                                     ],
#                                     "url": "https://t.co/pKFMhdtDAD"
#                                 }
#                             ]
#                         }
#                     },
#                     "favourites_count": 3607,
#                     "follow_request_sent": false,
#                     "followers_count": 43789,
#                     "following": false,
#                     "friends_count": 12,
#                     "geo_enabled": false,
#                     "has_extended_profile": false,
#                     "id": 867479700020621314,
#                     "id_str": "867479700020621314",
#                     "is_translation_enabled": false,
#                     "is_translator": false,
#                     "lang": "en",
#                     "listed_count": 172,
#                     "location": "",
#                     "name": "\u2728BTS SQUAD\u2728",
#                     "notifications": false,
#                     "profile_background_color": "000000",
#                     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                     "profile_background_tile": false,
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/867479700020621314/1505142765",
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/952137410153992192/Z0RIkJsI_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/952137410153992192/Z0RIkJsI_normal.jpg",
#                     "profile_link_color": "981CEB",
#                     "profile_sidebar_border_color": "000000",
#                     "profile_sidebar_fill_color": "000000",
#                     "profile_text_color": "000000",
#                     "profile_use_background_image": false,
#                     "protected": false,
#                     "screen_name": "Bitiiez_",
#                     "statuses_count": 3332,
#                     "time_zone": null,
#                     "translator_type": "none",
#                     "url": "https://t.co/pKFMhdtDAD",
#                     "utc_offset": null,
#                     "verified": false
#                 }
#             },
#             "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#             "text": "RT @Bitiiez_: Por alguna raz\u00f3n... me hacen acordar a estas otras \ud83d\udcf7\nTaehyung \u27a1\ufe0f Pollito Enojado\nJimin \u27a1\ufe0f a los tiburones(bailarines de Katy\u2026",
#             "truncated": false,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Wed Mar 15 01:02:07 +0000 2017",
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "description": "Estudiante de Arte Dram\u00e1tico\ud83c\udfad madre de 6 chilaquiles, entre otras cosas \ud83d\udc40",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "favourites_count": 9109,
#                 "follow_request_sent": false,
#                 "followers_count": 43,
#                 "following": false,
#                 "friends_count": 102,
#                 "geo_enabled": false,
#                 "has_extended_profile": true,
#                 "id": 841816745321103364,
#                 "id_str": "841816745321103364",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "es",
#                 "listed_count": 0,
#                 "location": "Salta, Argentina",
#                 "name": "J-Coeur",
#                 "notifications": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/841816745321103364/1498670005",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/952584203035709440/SRwUDPB__normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/952584203035709440/SRwUDPB__normal.jpg",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "protected": false,
#                 "screen_name": "Glowing_JuMaGa",
#                 "statuses_count": 3175,
#                 "time_zone": null,
#                 "translator_type": "none",
#                 "url": null,
#                 "utc_offset": null,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Mon Jan 15 18:31:42 +0000 2018",
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "urls": [],
#                 "user_mentions": [
#                     {
#                         "id": 24852465,
#                         "id_str": "24852465",
#                         "indices": [
#                             3,
#                             18
#                         ],
#                         "name": "Carly Rae Jepsen",
#                         "screen_name": "carlyraejepsen"
#                     }
#                 ]
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 952971571928289280,
#             "id_str": "952971571928289280",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "is_quote_status": false,
#             "lang": "en",
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "retweet_count": 380,
#             "retweeted": false,
#             "retweeted_status": {
#                 "contributors": null,
#                 "coordinates": null,
#                 "created_at": "Thu Dec 21 16:01:26 +0000 2017",
#                 "entities": {
#                     "hashtags": [],
#                     "symbols": [],
#                     "urls": [],
#                     "user_mentions": []
#                 },
#                 "favorite_count": 4044,
#                 "favorited": false,
#                 "geo": null,
#                 "id": 943874057228947461,
#                 "id_str": "943874057228947461",
#                 "in_reply_to_screen_name": null,
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "is_quote_status": false,
#                 "lang": "en",
#                 "metadata": {
#                     "iso_language_code": "en",
#                     "result_type": "recent"
#                 },
#                 "place": null,
#                 "retweet_count": 380,
#                 "retweeted": false,
#                 "scopes": {
#                     "followers": false
#                 },
#                 "source": "<a href=\"https://ads-api.twitter.com\" rel=\"nofollow\">Twitter Ads Composer</a>",
#                 "text": "Happy news\u2026 Hitting the road with Katy Perry this January and February! Come out and let\u2019s make it a party! \u270c\ud83c\udffb\ud83c\udfb6",
#                 "truncated": false,
#                 "user": {
#                     "contributors_enabled": false,
#                     "created_at": "Tue Mar 17 07:10:51 +0000 2009",
#                     "default_profile": false,
#                     "default_profile_image": false,
#                     "description": "",
#                     "entities": {
#                         "description": {
#                             "urls": []
#                         },
#                         "url": {
#                             "urls": [
#                                 {
#                                     "display_url": "smarturl.it/CutToTheFeeling",
#                                     "expanded_url": "http://smarturl.it/CutToTheFeeling",
#                                     "indices": [
#                                         0,
#                                         23
#                                     ],
#                                     "url": "https://t.co/aITpiHz4gv"
#                                 }
#                             ]
#                         }
#                     },
#                     "favourites_count": 2171,
#                     "follow_request_sent": false,
#                     "followers_count": 11032409,
#                     "following": false,
#                     "friends_count": 86225,
#                     "geo_enabled": true,
#                     "has_extended_profile": false,
#                     "id": 24852465,
#                     "id_str": "24852465",
#                     "is_translation_enabled": true,
#                     "is_translator": false,
#                     "lang": "en",
#                     "listed_count": 11055,
#                     "location": "",
#                     "name": "Carly Rae Jepsen",
#                     "notifications": false,
#                     "profile_background_color": "FF94DD",
#                     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme18/bg.gif",
#                     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme18/bg.gif",
#                     "profile_background_tile": false,
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/24852465/1486781315",
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/882791609934331905/yMrk9LYH_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/882791609934331905/yMrk9LYH_normal.jpg",
#                     "profile_link_color": "038543",
#                     "profile_sidebar_border_color": "FFFFFF",
#                     "profile_sidebar_fill_color": "E6F6F9",
#                     "profile_text_color": "333333",
#                     "profile_use_background_image": false,
#                     "protected": false,
#                     "screen_name": "carlyraejepsen",
#                     "statuses_count": 6717,
#                     "time_zone": "Quito",
#                     "translator_type": "regular",
#                     "url": "https://t.co/aITpiHz4gv",
#                     "utc_offset": -18000,
#                     "verified": true
#                 }
#             },
#             "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#             "text": "RT @carlyraejepsen: Happy news\u2026 Hitting the road with Katy Perry this January and February! Come out and let\u2019s make it a party! \u270c\ud83c\udffb\ud83c\udfb6",
#             "truncated": false,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Thu Jan 29 22:18:05 +0000 2015",
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "description": "#1 katycat! if you have a dream you have to go on a gourney to fulfil that dream -KATY PERRY",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "favourites_count": 3464,
#                 "follow_request_sent": false,
#                 "followers_count": 55,
#                 "following": false,
#                 "friends_count": 49,
#                 "geo_enabled": true,
#                 "has_extended_profile": false,
#                 "id": 3002576287,
#                 "id_str": "3002576287",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "en",
#                 "listed_count": 2,
#                 "location": "",
#                 "name": "katycat",
#                 "notifications": false,
#                 "profile_background_color": "C0DEED",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/3002576287/1470110883",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/729461566492446720/Uw3mkOzZ_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/729461566492446720/Uw3mkOzZ_normal.jpg",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "protected": false,
#                 "screen_name": "faithcharlie11",
#                 "statuses_count": 3671,
#                 "time_zone": null,
#                 "translator_type": "none",
#                 "url": null,
#                 "utc_offset": null,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Mon Jan 15 18:31:40 +0000 2018",
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "urls": [
#                     {
#                         "display_url": "twitter.com/i/web/status/9\u2026",
#                         "expanded_url": "https://twitter.com/i/web/status/952971562541559810",
#                         "indices": [
#                             102,
#                             125
#                         ],
#                         "url": "https://t.co/QHaNTLBZ9n"
#                     }
#                 ],
#                 "user_mentions": []
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 952971562541559810,
#             "id_str": "952971562541559810",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "is_quote_status": false,
#             "lang": "en",
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "possibly_sensitive": false,
#             "retweet_count": 0,
#             "retweeted": false,
#             "source": "<a href=\"http://www.destroytwitter.com\" rel=\"nofollow\">DestroyTwitter</a>",
#             "text": "Katy Perry Mocks Dallas' Bike-Share Problem During Over-the-Top 2-Hour Performance - Dallas Observer\u2026 https://t.co/QHaNTLBZ9n",
#             "truncated": true,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Tue Jan 12 17:54:18 +0000 2016",
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "description": "All the singer news you ever wanted, in one profile only!",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "favourites_count": 244,
#                 "follow_request_sent": false,
#                 "followers_count": 17530,
#                 "following": false,
#                 "friends_count": 3136,
#                 "geo_enabled": false,
#                 "has_extended_profile": false,
#                 "id": 4786373303,
#                 "id_str": "4786373303",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "en",
#                 "listed_count": 127,
#                 "location": "",
#                 "name": "Music World",
#                 "notifications": false,
#                 "profile_background_color": "000000",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/686971006389514240/knmb3b1j_normal.png",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/686971006389514240/knmb3b1j_normal.png",
#                 "profile_link_color": "3F48CC",
#                 "profile_sidebar_border_color": "000000",
#                 "profile_sidebar_fill_color": "000000",
#                 "profile_text_color": "000000",
#                 "profile_use_background_image": false,
#                 "protected": false,
#                 "screen_name": "MusicLoverWrld",
#                 "statuses_count": 190780,
#                 "time_zone": "Pacific Time (US & Canada)",
#                 "translator_type": "none",
#                 "url": null,
#                 "utc_offset": -28800,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Mon Jan 15 18:31:36 +0000 2018",
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "urls": [],
#                 "user_mentions": [
#                     {
#                         "id": 248329648,
#                         "id_str": "248329648",
#                         "indices": [
#                             3,
#                             13
#                         ],
#                         "name": "Sharp Williams",
#                         "screen_name": "SharpTusk"
#                     }
#                 ]
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 952971544518647810,
#             "id_str": "952971544518647810",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "is_quote_status": false,
#             "lang": "en",
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "retweet_count": 110,
#             "retweeted": false,
#             "retweeted_status": {
#                 "contributors": null,
#                 "coordinates": null,
#                 "created_at": "Sat Jan 13 05:53:31 +0000 2018",
#                 "entities": {
#                     "hashtags": [],
#                     "symbols": [],
#                     "urls": [
#                         {
#                             "display_url": "twitter.com/i/web/status/9\u2026",
#                             "expanded_url": "https://twitter.com/i/web/status/952055990895218688",
#                             "indices": [
#                                 121,
#                                 144
#                             ],
#                             "url": "https://t.co/66oTBuLVoX"
#                         }
#                     ],
#                     "user_mentions": []
#                 },
#                 "favorite_count": 299,
#                 "favorited": false,
#                 "geo": null,
#                 "id": 952055990895218688,
#                 "id_str": "952055990895218688",
#                 "in_reply_to_screen_name": null,
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "is_quote_status": false,
#                 "lang": "en",
#                 "metadata": {
#                     "iso_language_code": "en",
#                     "result_type": "recent"
#                 },
#                 "place": null,
#                 "possibly_sensitive": false,
#                 "retweet_count": 110,
#                 "retweeted": false,
#                 "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#                 "text": "The Hog Call at the Katy Perry Concert. Her dad, originally from Memphis, on the telephone did a small Hog Call &amp; g\u2026 https://t.co/66oTBuLVoX",
#                 "truncated": true,
#                 "user": {
#                     "contributors_enabled": false,
#                     "created_at": "Sun Feb 06 19:30:14 +0000 2011",
#                     "default_profile": false,
#                     "default_profile_image": false,
#                     "description": "FWAA Member; Expert on Early Arkansas Razorback Athletic Department & Football History; Book Coming Soon! Writer on @HogDatabase.",
#                     "entities": {
#                         "description": {
#                             "urls": []
#                         },
#                         "url": {
#                             "urls": [
#                                 {
#                                     "display_url": "hogdb.com",
#                                     "expanded_url": "http://hogdb.com",
#                                     "indices": [
#                                         0,
#                                         23
#                                     ],
#                                     "url": "https://t.co/E112xCpQlN"
#                                 }
#                             ]
#                         }
#                     },
#                     "favourites_count": 52547,
#                     "follow_request_sent": false,
#                     "followers_count": 5772,
#                     "following": false,
#                     "friends_count": 5508,
#                     "geo_enabled": true,
#                     "has_extended_profile": true,
#                     "id": 248329648,
#                     "id_str": "248329648",
#                     "is_translation_enabled": false,
#                     "is_translator": false,
#                     "lang": "en",
#                     "listed_count": 155,
#                     "location": "Little Rock, AR",
#                     "name": "Sharp Williams",
#                     "notifications": false,
#                     "profile_background_color": "BE0F35",
#                     "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/378800000148275252/ivbLv0-B.jpeg",
#                     "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/378800000148275252/ivbLv0-B.jpeg",
#                     "profile_background_tile": true,
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/248329648/1511569750",
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/3132355190/5fb54fd1de1ff253fcb22e134b27bade_normal.png",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/3132355190/5fb54fd1de1ff253fcb22e134b27bade_normal.png",
#                     "profile_link_color": "BE0F35",
#                     "profile_sidebar_border_color": "FFFFFF",
#                     "profile_sidebar_fill_color": "DDEEF6",
#                     "profile_text_color": "333333",
#                     "profile_use_background_image": true,
#                     "protected": false,
#                     "screen_name": "SharpTusk",
#                     "statuses_count": 120503,
#                     "time_zone": "America/Chicago",
#                     "translator_type": "none",
#                     "url": "https://t.co/E112xCpQlN",
#                     "utc_offset": -21600,
#                     "verified": false
#                 }
#             },
#             "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#             "text": "RT @SharpTusk: The Hog Call at the Katy Perry Concert. Her dad, originally from Memphis, on the telephone did a small Hog Call &amp; got things\u2026",
#             "truncated": false,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Sun Mar 05 07:07:33 +0000 2017",
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "description": "nea | u of a alumna",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     },
#                     "url": {
#                         "urls": [
#                             {
#                                 "display_url": "instagram.com/algrayg/",
#                                 "expanded_url": "http://www.instagram.com/algrayg/",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ],
#                                 "url": "https://t.co/EwbHkQKA6X"
#                             }
#                         ]
#                     }
#                 },
#                 "favourites_count": 1408,
#                 "follow_request_sent": false,
#                 "followers_count": 160,
#                 "following": false,
#                 "friends_count": 248,
#                 "geo_enabled": true,
#                 "has_extended_profile": true,
#                 "id": 838284831419207680,
#                 "id_str": "838284831419207680",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "en",
#                 "listed_count": 0,
#                 "location": "870",
#                 "name": "ally G",
#                 "notifications": false,
#                 "profile_background_color": "000000",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/838284831419207680/1513029238",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/950542220863725568/ZzmEJhf3_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/950542220863725568/ZzmEJhf3_normal.jpg",
#                 "profile_link_color": "7FDBB6",
#                 "profile_sidebar_border_color": "000000",
#                 "profile_sidebar_fill_color": "000000",
#                 "profile_text_color": "000000",
#                 "profile_use_background_image": false,
#                 "protected": false,
#                 "screen_name": "algrayg",
#                 "statuses_count": 503,
#                 "time_zone": null,
#                 "translator_type": "none",
#                 "url": "https://t.co/EwbHkQKA6X",
#                 "utc_offset": null,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Mon Jan 15 18:31:28 +0000 2018",
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "urls": [],
#                 "user_mentions": [
#                     {
#                         "id": 906592575259332608,
#                         "id_str": "906592575259332608",
#                         "indices": [
#                             3,
#                             15
#                         ],
#                         "name": "Lady Gaga Charts",
#                         "screen_name": "charts_lady"
#                     }
#                 ]
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 952971513384218624,
#             "id_str": "952971513384218624",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "is_quote_status": false,
#             "lang": "en",
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "retweet_count": 69,
#             "retweeted": false,
#             "retweeted_status": {
#                 "contributors": null,
#                 "coordinates": null,
#                 "created_at": "Mon Jan 15 14:53:14 +0000 2018",
#                 "entities": {
#                     "hashtags": [],
#                     "symbols": [],
#                     "urls": [
#                         {
#                             "display_url": "twitter.com/i/web/status/9\u2026",
#                             "expanded_url": "https://twitter.com/i/web/status/952916590382780417",
#                             "indices": [
#                                 117,
#                                 140
#                             ],
#                             "url": "https://t.co/0ivAEk7Zq3"
#                         }
#                     ],
#                     "user_mentions": []
#                 },
#                 "favorite_count": 248,
#                 "favorited": false,
#                 "geo": null,
#                 "id": 952916590382780417,
#                 "id_str": "952916590382780417",
#                 "in_reply_to_screen_name": null,
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "is_quote_status": false,
#                 "lang": "en",
#                 "metadata": {
#                     "iso_language_code": "en",
#                     "result_type": "recent"
#                 },
#                 "place": null,
#                 "possibly_sensitive": false,
#                 "retweet_count": 69,
#                 "retweeted": false,
#                 "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#                 "text": "Only Females with Solo Diamond Certificated Singles in United States \ud83c\uddfa\ud83c\uddf8 \ud83d\udc8e \n\n#1 Katy Perry \n#2 Lady Gaga \n#3 Lorde\n#\u2026 https://t.co/0ivAEk7Zq3",
#                 "truncated": true,
#                 "user": {
#                     "contributors_enabled": false,
#                     "created_at": "Sat Sep 09 18:58:08 +0000 2017",
#                     "default_profile": false,
#                     "default_profile_image": false,
#                     "description": "Best Source about Gaga\u2019s charts and news. New Giveaway every week \ud83d\udc9e",
#                     "entities": {
#                         "description": {
#                             "urls": []
#                         }
#                     },
#                     "favourites_count": 4381,
#                     "follow_request_sent": false,
#                     "followers_count": 5791,
#                     "following": false,
#                     "friends_count": 5459,
#                     "geo_enabled": false,
#                     "has_extended_profile": true,
#                     "id": 906592575259332608,
#                     "id_str": "906592575259332608",
#                     "is_translation_enabled": false,
#                     "is_translator": false,
#                     "lang": "de",
#                     "listed_count": 45,
#                     "location": "New York, NY",
#                     "name": "Lady Gaga Charts",
#                     "notifications": false,
#                     "profile_background_color": "000000",
#                     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                     "profile_background_tile": false,
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/906592575259332608/1515614295",
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/951180230890278912/S0RrbO-I_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/951180230890278912/S0RrbO-I_normal.jpg",
#                     "profile_link_color": "981CEB",
#                     "profile_sidebar_border_color": "000000",
#                     "profile_sidebar_fill_color": "000000",
#                     "profile_text_color": "000000",
#                     "profile_use_background_image": false,
#                     "protected": false,
#                     "screen_name": "charts_lady",
#                     "statuses_count": 1127,
#                     "time_zone": null,
#                     "translator_type": "none",
#                     "url": null,
#                     "utc_offset": null,
#                     "verified": false
#                 }
#             },
#             "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#             "text": "RT @charts_lady: Only Females with Solo Diamond Certificated Singles in United States \ud83c\uddfa\ud83c\uddf8 \ud83d\udc8e \n\n#1 Katy Perry \n#2 Lady Gaga \n#3 Lorde\n#4 Carly\u2026",
#             "truncated": false,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Wed May 04 22:33:14 +0000 2011",
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "description": "@carlyraejepsen @fifthharmony",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "favourites_count": 25642,
#                 "follow_request_sent": false,
#                 "followers_count": 1519,
#                 "following": false,
#                 "friends_count": 159,
#                 "geo_enabled": true,
#                 "has_extended_profile": true,
#                 "id": 293189197,
#                 "id_str": "293189197",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "es",
#                 "listed_count": 25,
#                 "location": "",
#                 "name": "rafael",
#                 "notifications": false,
#                 "profile_background_color": "131516",
#                 "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/664914359768907776/MgHJWc7c.jpg",
#                 "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/664914359768907776/MgHJWc7c.jpg",
#                 "profile_background_tile": true,
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/293189197/1515977880",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/945894454203944960/7n9pSHfL_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/945894454203944960/7n9pSHfL_normal.jpg",
#                 "profile_link_color": "FA743E",
#                 "profile_sidebar_border_color": "000000",
#                 "profile_sidebar_fill_color": "000000",
#                 "profile_text_color": "000000",
#                 "profile_use_background_image": true,
#                 "protected": false,
#                 "screen_name": "radvqc",
#                 "statuses_count": 34625,
#                 "time_zone": "Central Time (US & Canada)",
#                 "translator_type": "regular",
#                 "url": null,
#                 "utc_offset": -21600,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Mon Jan 15 18:31:28 +0000 2018",
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "urls": [
#                     {
#                         "display_url": "thaiticketmajor.com/concert/katy-p\u2026",
#                         "expanded_url": "http://thaiticketmajor.com/concert/katy-perry-witness-the-tour-2018-bkk-en.html",
#                         "indices": [
#                             113,
#                             136
#                         ],
#                         "url": "https://t.co/qaZIsT6NXs"
#                     }
#                 ],
#                 "user_mentions": [
#                     {
#                         "id": 21447363,
#                         "id_str": "21447363",
#                         "indices": [
#                             3,
#                             13
#                         ],
#                         "name": "KATY PERRY",
#                         "screen_name": "katyperry"
#                     }
#                 ]
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 952971511236833280,
#             "id_str": "952971511236833280",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "is_quote_status": false,
#             "lang": "en",
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "possibly_sensitive": false,
#             "retweet_count": 2829,
#             "retweeted": false,
#             "retweeted_status": {
#                 "contributors": null,
#                 "coordinates": null,
#                 "created_at": "Sat Jan 13 07:12:01 +0000 2018",
#                 "entities": {
#                     "hashtags": [],
#                     "symbols": [],
#                     "urls": [
#                         {
#                             "display_url": "twitter.com/i/web/status/9\u2026",
# ...
#                 "contributors": null,
#                 "coordinates": null,
#                 "created_at": "Mon Jan 15 18:17:58 +0000 2018",
#                 "entities": {
#                     "hashtags": [
#                         {
#                             "indices": [
#                                 92,
#                                 112
#                             ],
#                             "text": "BRITVIDCALVINHARRIS"
#                         }
#                     ],
#                     "media": [
#                         {
#                             "display_url": "pic.twitter.com/VRKLEC6eee",
#                             "expanded_url": "https://twitter.com/KatyP_Nation/status/952968113150185472/photo/1",
#                             "id": 952968109949939713,
#                             "id_str": "952968109949939713",
#                             "indices": [
#                                 113,
#                                 136
#                             ],
#                             "media_url": "http://pbs.twimg.com/media/DTmfcmvXcAEkMJo.jpg",
#                             "media_url_https": "https://pbs.twimg.com/media/DTmfcmvXcAEkMJo.jpg",
#                             "sizes": {
#                                 "large": {
#                                     "h": 615,
#                                     "resize": "fit",
#                                     "w": 460
#                                 },
#                                 "medium": {
#                                     "h": 615,
#                                     "resize": "fit",
#                                     "w": 460
#                                 },
#                                 "small": {
#                                     "h": 615,
#                                     "resize": "fit",
#                                     "w": 460
#                                 },
#                                 "thumb": {
#                                     "h": 150,
#                                     "resize": "crop",
#                                     "w": 150
#                                 }
#                             },
#                             "type": "photo",
#                             "url": "https://t.co/VRKLEC6eee"
#                         }
#                     ],
#                     "symbols": [],
#                     "urls": [],
#                     "user_mentions": []
#                 },
#                 "extended_entities": {
#                     "media": [
#                         {
#                             "display_url": "pic.twitter.com/VRKLEC6eee",
#                             "expanded_url": "https://twitter.com/KatyP_Nation/status/952968113150185472/photo/1",
#                             "id": 952968109949939713,
#                             "id_str": "952968109949939713",
#                             "indices": [
#                                 113,
#                                 136
#                             ],
#                             "media_url": "http://pbs.twimg.com/media/DTmfcmvXcAEkMJo.jpg",
#                             "media_url_https": "https://pbs.twimg.com/media/DTmfcmvXcAEkMJo.jpg",
#                             "sizes": {
#                                 "large": {
#                                     "h": 615,
#                                     "resize": "fit",
#                                     "w": 460
#                                 },
#                                 "medium": {
#                                     "h": 615,
#                                     "resize": "fit",
#                                     "w": 460
#                                 },
#                                 "small": {
#                                     "h": 615,
#                                     "resize": "fit",
#                                     "w": 460
#                                 },
#                                 "thumb": {
#                                     "h": 150,
#                                     "resize": "crop",
#                                     "w": 150
#                                 }
#                             },
#                             "type": "photo",
#                             "url": "https://t.co/VRKLEC6eee"
#                         }
#                     ]
#                 },
#                 "favorite_count": 5,
#                 "favorited": false,
#                 "geo": null,
#                 "id": 952968113150185472,
#                 "id_str": "952968113150185472",
#                 "in_reply_to_screen_name": null,
#                 "in_reply_to_status_id": null,
#                 "in_reply_to_status_id_str": null,
#                 "in_reply_to_user_id": null,
#                 "in_reply_to_user_id_str": null,
#                 "is_quote_status": false,
#                 "lang": "pt",
#                 "metadata": {
#                     "iso_language_code": "pt",
#                     "result_type": "recent"
#                 },
#                 "place": null,
#                 "possibly_sensitive": false,
#                 "retweet_count": 7,
#                 "retweeted": false,
#                 "source": "<a href=\"http://www.twitter.com\" rel=\"nofollow\">Twitter for Windows Phone</a>",
#                 "text": "\"Ela tem planos para 2018\", CEO da Capitol revela que Katy Perry tem planos para esse ano.\r\r#BRITVIDCALVINHARRIS https://t.co/VRKLEC6eee",
#                 "truncated": false,
#                 "user": {
#                     "contributors_enabled": false,
#                     "created_at": "Sat Oct 22 16:29:58 +0000 2016",
#                     "default_profile": false,
#                     "default_profile_image": false,
#                     "description": "Sua mais nova fonte, criada na inten\u00e7\u00e3o de ajudar e informar f\u00e3s da cantora-compositora Katy Perry, fazemos atualiza\u00e7\u00f5es de charts, visualiza\u00e7\u00f5es e muito mais.",
#                     "entities": {
#                         "description": {
#                             "urls": []
#                         },
#                         "url": {
#                             "urls": [
#                                 {
#                                     "display_url": "web.facebook.com/nationkatyperr\u2026",
#                                     "expanded_url": "https://web.facebook.com/nationkatyperry/",
#                                     "indices": [
#                                         0,
#                                         23
#                                     ],
#                                     "url": "https://t.co/FDFMuY7Fn9"
#                                 }
#                             ]
#                         }
#                     },
#                     "favourites_count": 421,
#                     "follow_request_sent": false,
#                     "followers_count": 1860,
#                     "following": false,
#                     "friends_count": 110,
#                     "geo_enabled": false,
#                     "has_extended_profile": true,
#                     "id": 789866396125696000,
#                     "id_str": "789866396125696000",
#                     "is_translation_enabled": false,
#                     "is_translator": false,
#                     "lang": "pt",
#                     "listed_count": 21,
#                     "location": "Worldwide",
#                     "name": "KATY PERRY NATION",
#                     "notifications": false,
#                     "profile_background_color": "000000",
#                     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                     "profile_background_tile": false,
#                     "profile_banner_url": "https://pbs.twimg.com/profile_banners/789866396125696000/1516040775",
#                     "profile_image_url": "http://pbs.twimg.com/profile_images/952970185350303749/hVRwo5X1_normal.jpg",
#                     "profile_image_url_https": "https://pbs.twimg.com/profile_images/952970185350303749/hVRwo5X1_normal.jpg",
#                     "profile_link_color": "E81C4F",
#                     "profile_sidebar_border_color": "000000",
#                     "profile_sidebar_fill_color": "000000",
#                     "profile_text_color": "000000",
#                     "profile_use_background_image": false,
#                     "protected": false,
#                     "screen_name": "KatyP_Nation",
#                     "statuses_count": 4834,
#                     "time_zone": "Brasilia",
#                     "translator_type": "none",
#                     "url": "https://t.co/FDFMuY7Fn9",
#                     "utc_offset": -7200,
#                     "verified": false
#                 }
#             },
#             "source": "<a href=\"http://www.twitter.com\" rel=\"nofollow\">Twitter for Windows Phone</a>",
#             "text": "RT @KatyP_Nation: \"Ela tem planos para 2018\", CEO da Capitol revela que Katy Perry tem planos para esse ano.\r\r#BRITVIDCALVINHARRIS https://\u2026",
#             "truncated": false,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Tue Mar 14 15:57:13 +0000 2017",
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "description": "Conta para Mutir\u00f5es da @KatyP_Nation.",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "favourites_count": 1884,
#                 "follow_request_sent": false,
#                 "followers_count": 259,
#                 "following": false,
#                 "friends_count": 95,
#                 "geo_enabled": false,
#                 "has_extended_profile": false,
#                 "id": 841679616725176321,
#                 "id_str": "841679616725176321",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "pt",
#                 "listed_count": 2,
#                 "location": "nationkaty@gmail.com",
#                 "name": "KPN MUTIR\u00c3O",
#                 "notifications": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/841679616725176321/1501710946",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/951860562316742656/XXna8zCk_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/951860562316742656/XXna8zCk_normal.jpg",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "protected": false,
#                 "screen_name": "kpnmutirao",
#                 "statuses_count": 5686,
#                 "time_zone": null,
#                 "translator_type": "none",
#                 "url": null,
#                 "utc_offset": null,
#                 "verified": false
#             }
#         },
#         {
#             "contributors": null,
#             "coordinates": null,
#             "created_at": "Mon Jan 15 18:18:15 +0000 2018",
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "urls": [
#                     {
#                         "display_url": "ift.tt/2DcZhYB",
#                         "expanded_url": "http://ift.tt/2DcZhYB",
#                         "indices": [
#                             116,
#                             139
#                         ],
#                         "url": "https://t.co/FsETZFMBC5"
#                     }
#                 ],
#                 "user_mentions": []
#             },
#             "favorite_count": 0,
#             "favorited": false,
#             "geo": null,
#             "id": 952968186294566914,
#             "id_str": "952968186294566914",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "is_quote_status": false,
#             "lang": "en",
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "place": null,
#             "possibly_sensitive": false,
#             "retweet_count": 0,
#             "retweeted": false,
#             "source": "<a href=\"https://ifttt.com\" rel=\"nofollow\">IFTTT</a>",
#             "text": "New Katy News: Katy Perry Mocks Dallas' Bike-Share Problem During Over-the-Top 2-Hour Performance - Dallas Observer https://t.co/FsETZFMBC5",
#             "truncated": false,
#             "user": {
#                 "contributors_enabled": false,
#                 "created_at": "Thu Feb 16 21:24:00 +0000 2017",
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "description": "Latest news and updates from Katy Perry via @ATRL. New music discussion and announcements, fan debates and more.",
#                 "entities": {
#                     "description": {
#                         "urls": []
#                     },
#                     "url": {
#                         "urls": [
#                             {
#                                 "display_url": "atrl.net/forums/topic/3\u2026",
#                                 "expanded_url": "https://atrl.net/forums/topic/308-katy-perry/",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ],
#                                 "url": "https://t.co/MHOnFH9ZQ6"
#                             }
#                         ]
#                     }
#                 },
#                 "favourites_count": 0,
#                 "follow_request_sent": false,
#                 "followers_count": 63,
#                 "following": false,
#                 "friends_count": 14,
#                 "geo_enabled": false,
#                 "has_extended_profile": false,
#                 "id": 832339771158568961,
#                 "id_str": "832339771158568961",
#                 "is_translation_enabled": false,
#                 "is_translator": false,
#                 "lang": "en-gb",
#                 "listed_count": 3,
#                 "location": "ATRL.net",
#                 "name": "Katy Perry ATRL",
#                 "notifications": false,
#                 "profile_background_color": "000000",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/832339771158568961/1487282393",
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/832345884155314177/Li1my_GC_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/832345884155314177/Li1my_GC_normal.jpg",
#                 "profile_link_color": "7E0403",
#                 "profile_sidebar_border_color": "000000",
#                 "profile_sidebar_fill_color": "000000",
#                 "profile_text_color": "000000",
#                 "profile_use_background_image": false,
#                 "protected": false,
#                 "screen_name": "KatyATRL",
#                 "statuses_count": 12437,
#                 "time_zone": null,
#                 "translator_type": "none",
#                 "url": "https://t.co/MHOnFH9ZQ6",
#                 "utc_offset": null,
#                 "verified": false
#             }
#         }
#     ]
# }

# %%
# "Real Person" Filters
min_tweets = 5
max_tweets = 10000
max_followers = 2500
max_following = 2500
lang = "en"

# Array of Eligible Tweets
tweet_array = []

# %%
# Print Tweets
for tweet in public_tweets["statuses"]:
    # Use filters to check if user meets conditions
    if (tweet["user"]["followers_count"] < max_followers and
        tweet["user"]["statuses_count"] > min_tweets and
        tweet["user"]["statuses_count"] < max_tweets and
        tweet["user"]["friends_count"] < max_following and
            tweet["user"]["lang"] == lang
       ):

        # If so add the user's tweet to the array (for future use)
        tweet_array.append(tweet["text"])

        # Print the username
        print(tweet["user"]["screen_name"])

        # Print the tweet text
        print(tweet["text"])
        print("")

# Print total number of tweets
print(len(tweet_array))
# Out:
# faithcharlie11
# RT @carlyraejepsen: Happy news… Hitting the road with Katy Perry this January and February! Come out and let’s make it a party! ✌🏻🎶
#
# algrayg
# RT @SharpTusk: The Hog Call at the Katy Perry Concert. Her dad, originally from Memphis, on the telephone did a small Hog Call &amp; got things…
#
# Katy_Perry_24_7
# I liked a @YouTube video https://t.co/XkRRpjLGH2 Taylor Swift • Look What You Made Me Do (Behind The Scenes Full / Detrás de
#
# abscenced
# RT @charts_lady: Only Females with Solo Diamond Certificated Singles in United States 🇺🇸 💎
#
# #1 Katy Perry
# #2 Lady Gaga
# #3 Lorde
# #4 Carly…
#
# BenKalsi
# Just spent an obscene amount of money to see Katy Perry in June 😭
#
# taraanouri
# Vill hitta någon som Katy Perry sjunger om i teenage dream
#
# ambermgross1998
# RT @TheFactsOfShade: Taylor Swift’s 3+ year old album, ‘1989’, is still charting on the Billboard 200 at #74, Katy Perry’s ‘Witness’ isn’t…
#
# kth_5251997
# RT @Bitiiez_: Por alguna razón... me hacen acordar a estas otras 📷
# Taehyung ➡️ Pollito Enojado
# Jimin ➡️ a los tiburones(bailarines de Katy…
#
# DJBUBBY1710
# I liked a @YouTube video https://t.co/3RP2ED6HHr Swalla To The Rhythm - Jason Derulo &amp; Katy Perry ft. Nicki Minaj &amp; Skip Marley (Mixed
#
# fuckingmadelyn
# “Chasing Cars? Snow Patrol. Do you know this song?”
# My kid is at the start of her music fan journey and it is fasci… https://t.co/XdQeeOwA4R
#
# Rumbellion
# Fifth Harmony, Katy Perry, and Niall Horan https://t.co/96Pg2sLExJ
#
# 44IDarker
# RT @tomsappetite: Amazon Echo: Katy Perry edition (part 1/2) https://t.co/6yLnl6I4wc
#
# wanqster
# I liked a @YouTube video https://t.co/fnx7nzYgnc Katy Perry - Birthday (Lyric Video)
#
# KatyPerryNewsBt
# Katy Perry Mocks Dallas' Bike-Share Problem During Over-the-Top 2-Hour Performance https://t.co/Qh5SmrVHPi
#
# 42
