# %% [markdown]
# ## Seek, Create, Update, and Destroy (0:20)

# %%
from sqlalchemy import create_engine
import pandas as pd
from warnings import filterwarnings
import pymysql
filterwarnings('ignore', category=pymysql.Warning)
import os

# %%
engine = create_engine('mysql+pymysql://root:AQib.21Talib@localhost')  # connect to server
engine.execute("create database if not exists firepower") #create db
engine = create_engine('mysql+pymysql://root:AQib.21Talib@localhost/firepower')

# %%
def RunSQL(sql_command):
    connection = pymysql.connect(host='localhost',
                             user='root',
                             password='AQib.21Talib',
                             db='firepower',
                             charset='utf8mb4',
                             cursorclass=pymysql.cursors.DictCursor)
    try:
        with connection.cursor() as cursor:
            commands = sql_command.split(';')
            for command in commands:
                if command == '\n': continue
                cursor.execute(command + ';')
                connection.commit()
    except Exception as e: 
        print(e)
    finally:
        connection.close()

# %%
file_name = os.path.join('resources', 'GlobalFirePower.csv')
df = pd.read_csv(file_name)
df.head()
# Out:
#          Country ISO3  Rank  Total Population  Manpower Available  \
# 0  United States  USA     1         323995528           145215000
# 1         Russia  RUS     2         142355415            70000000
# 2          China  CHN     3        1373541278           750000000
# 3          India  IND     4        1266883598           616000000
# 4         France  FRA     5          66836154            30000000
#
#    Fit-for-Service  Reaching Military Age  Total Military Personnel  \
# 0        120025000                4220000                   2363675
# 1         47000000                1355000                   3371027
# 2        619000000               19550000                   3712500
# 3        489600000               22900000                   4207250
# 4         23750000                 775000                    387635
#
#    Active Personnel  Reserve Personnel       ...        Railway Coverage (km)  \
# ...

# %%
df.columns = df.columns.str.replace('\s+', '_')

# %%
df.to_sql(con=engine, name='military', if_exists='replace', index=False)

# %%
new_df = pd.read_sql_query('select * from military', engine)
new_df
# Out:
#                       Country ISO3  Rank  Total_Population  \
# 0               United States  USA     1         323995528
# 1                      Russia  RUS     2         142355415
# 2                       China  CHN     3        1373541278
# 3                       India  IND     4        1266883598
# 4                      France  FRA     5          66836154
# 5              United Kingdom  UKD     6          64430428
# 6                       Japan  JPN     7         126702133
# 7                      Turkey  TUR     8          80274604
# 8                     Germany  GER     9          80722792
# 9                       Egypt  EGP    10          94666993
# 10                      Italy  ITA    11          62007540
# 11                South Korea  SKO    12          50924172
# 12                   Pakistan  PAK    13         201995540
# 13                  Indonesia  INO    14         258316051
# 14                     Israel  ISR    15           8174527
# ...

# %%
new_df.columns
# Out:
# Index(['Country', 'ISO3', 'Rank', 'Total_Population', 'Manpower_Available',
#        'Fit-for-Service', 'Reaching_Military_Age', 'Total_Military_Personnel',
#        'Active_Personnel', 'Reserve_Personnel', 'Total_Aircraft_Strength',
#        'Fighter_Aircraft', 'Attack_Aircraft', 'Transport_Aircraft',
#        'Trainer_Aircraft', 'Total_Helicopter_Strength', 'Attack_Helicopters',
#        'Combat_Tanks', 'Armored_Fighting_Vehicles', 'Self-Propelled_Artillery',
#        'Towed_Artillery', 'Rocket_Projectors', 'Total_Naval_Assets',
#        'Aircraft_Carriers', 'Frigates', 'Destroyers', 'Corvettes',
#        'Submarines', 'Patrol_Craft', 'Mine_Warfare_Vessels',
#        'Production_(bbl/dy)', 'Consumption_(bbl/dy)', 'Proven_Reserves_(bbl)',
#        'Labor_Force', 'Merchant_Marine_Strength', 'Major_Ports_/_Terminals',
#        'Roadway_Coverage_(km)', 'Railway_Coverage_(km)',
#        'Serivecable_Airports', 'Defense_Budget', 'External_Debt',
# ...

# %% [markdown]
# * Find all of those rows that have a "Reserve_Personnel" of 0 and then remove these rows from the dataset.
#
# * Use the `delete from` sql command.

# %%
# TODO: Fill in the SQL Query Below
sql_command = """
delete from military 
where Reserve_Personnel = 0;
"""
RunSQL(sql_command)

# %% [markdown]
# * Every country in the world at least deserves one "FighterAircraft". Only seems fair. Lets add one to each nation that has none.

# %%
# TODO: Fill in the SQL Query Below..
# something along the lines of UPDATE table SET value=1 WHERE value=0
sql_command = """
update military 
set Fighter_Aircraft=1 
where Fighter_Aircraft=0
"""
RunSQL(sql_command)

# %% [markdown]
# * Oh no! By updating this column, the values within "TotalAircraftStrength" column are now off for those nations! We've got to [add one](https://stackoverflow.com/a/2680352) to the original number.

# %%
sql_command = """
update military
set Total_Aircraft_Strength = Total_Aircraft_Strength + 1
where Fighter_Aircraft=1
"""
RunSQL(sql_command)

# %% [markdown]
# * A new nation has been founded and you are declared its leader! Congratulations! Unfortunately for you, every other nation is now looking to take over your land. Perform some calcuations to find the [Averages](https://www.w3schools.com/sql/sql_count_avg_sum.asp) for each the "Total" columns, take note of them, and then set those as the values for your nation's military.

# %%
# avg(Total_military_Personal)
new_df1 = pd.read_sql_query('select avg(Total_Military_Personnel) from military', engine)
new_df1
# Out:
#    avg(Total_Military_Personnel)
# 0                    524357.6071

# %%
# avg(Total_Aircraft_Strength)
new_df2 = pd.read_sql_query('select avg(Total_Aircraft_Strength) from military', engine)
new_df2
# Out:
#    avg(Total_Aircraft_Strength)
# 0                      456.5625

# %%
# avg(Total_Helicopter_Strength)
new_df3 = pd.read_sql_query('select avg(Total_Helicopter_Strength) from military', engine)
new_df3
# Out:
#    avg(Total_Helicopter_Strength)
# 0                        182.6518

# %%
# avg(Total_Population)
new_df4 = pd.read_sql_query('select avg(Total_Population) from military', engine)
new_df4
# Out:
#    avg(Total_Population)
# 0           6.006902e+07

# %% [markdown]
# * With the averages formed above for each the "Total" columns, take note of them, and then set those as the values for your nation's military. Insert these values into the database with your country's name

# %%
#TODO
sql_command = """
insert into military (Country, Total_Military_Personnel, Total_Aircraft_Strength, Total_Helicopter_Strength, Total_Population)
values ("Waynes World", 524357.6071, 456.5625, 182.6518, 6.006902e+07)
"""
RunSQL(sql_command)

# %% [markdown]
# * **Bonus**:
#
#     * After creating your new nation and some parts of your military strategies, go through each column in the newly created row and update their values in any way that you desire!

# %%
new_df5 = pd.read_sql_query('select * from military', engine)
new_df5
# Out:
#                    Country  ISO3   Rank  Total_Population  Manpower_Available  \
# 0            United States   USA    1.0         323995528         145215000.0
# 1                   Russia   RUS    2.0         142355415          70000000.0
# 2                    China   CHN    3.0        1373541278         750000000.0
# 3                    India   IND    4.0        1266883598         616000000.0
# 4                   France   FRA    5.0          66836154          30000000.0
# 5           United Kingdom   UKD    6.0          64430428          30000000.0
# 6                    Japan   JPN    7.0         126702133          54000000.0
# 7                   Turkey   TUR    8.0          80274604          41640000.0
# 8                  Germany   GER    9.0          80722792          37000000.0
# 9                    Egypt   EGP   10.0          94666993          42000000.0
# 10                   Italy   ITA   11.0          62007540          28000000.0
# ...
