# %%
import time
from splinter import Browser
from bs4 import BeautifulSoup
import pandas as pd
from selenium import webdriver

# %%
from sys import platform
if platform == "darwin":
    executable_path = {"executable_path": "/usr/local/bin/chromedriver"}
else:
    executable_path = {"executable_path": "C:\_chome\chromedriver.exe"}
browser = Browser("chrome", **executable_path, headless=False)

# %% [markdown]
# ### Mac:
# * brew install chromedriver
#
# ### Windows:
# * https://sites.google.com/a/chromium.org/chromedriver/downloads

# %%
listings = {}
url = "https://kansascity.craigslist.org/search/hhh?max_price=1500&availabilityMode=0"
browser.visit(url)
time.sleep(1)

html = browser.html
soup = BeautifulSoup(html, "html.parser")

listings["headline"] = soup.find_all("a", class_="result-title")
listings["price"] = soup.find_all("span", class_="result-price")
listings["hood"] = soup.find_all("span", class_="result-hood")

# %%
listings
# Out:
# {'headline': [<a class="result-title hdrlnk" data-id="6490543634" href="https://kansascity.craigslist.org/apa/d/the-interior-of-the-house-has/6490543634.html">the interior of the house has an open layout</a>,
#   <a class="result-title hdrlnk" data-id="6506270654" href="https://kansascity.craigslist.org/apa/d/1-bedroom-apartment-on-the/6506270654.html">1 Bedroom Apartment on the Plaza</a>,
#   <a class="result-title hdrlnk" data-id="6514879699" href="https://kansascity.craigslist.org/apa/d/one-bedroom-one-bath/6514879699.html">ONE Bedroom ONE bath apartment! READY NOW!</a>,
#   <a class="result-title hdrlnk" data-id="6520675231" href="https://kansascity.craigslist.org/apa/d/spacious-apartments-and-town/6520675231.html">Spacious Apartments and Town Homes!</a>,
#   <a class="result-title hdrlnk" data-id="6520673008" href="https://kansascity.craigslist.org/roo/d/room-for-rent/6520673008.html">Room for rent</a>,
# ...

# %%
soup.find
