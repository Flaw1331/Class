# %%
# Dependencies
from bs4 import BeautifulSoup
import requests

# URL of page to be scraped
url = 'https://kansascity.craigslist.org/search/sss?sort=rel&query=guitar'

# %%
# Retrieve page with the requests module
response = requests.get(url)
# Create BeautifulSoup object; parse with 'html.parser'
soup = BeautifulSoup(response.text, 'html.parser')

# Examine the results, then determine element that contains sought info
print(soup.prettify())
# Out:
# ﻿
# <!DOCTYPE html>
# <html class="no-js">
#  <head>
#   <title>
#    kansas city for sale "guitar" - craigslist
#   </title>
#   <meta content='kansas city for sale "guitar" - craigslist' name="description"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible">
#    <link href="https://kansascity.craigslist.org/search/sss" rel="canonical"/>
#    <link href="https://kansascity.craigslist.org/search/sss?format=rss&amp;query=guitar&amp;sort=rel" rel="alternate" title='RSS feed for craigslist | kansas city for sale "guitar" - craigslist' type="application/rss+xml"/>
#    <link href="https://kansascity.craigslist.org/search/sss?s=120&amp;query=guitar&amp;sort=rel" rel="next"/>
#    <meta content="width=device-width,initial-scale=1" name="viewport"/>
#    <link href="//www.craigslist.org/styles/cl.css?v=f2b739aac0ce30a61818c1630276321d" media="all" rel="stylesheet" type="text/css"/>
# ...

# %%
with open("craigslist.html", "w") as file:
    file.write(response.text)

# %% [markdown]
# To find results, it's often easier to use Visual Studio Code than scrolling through IPython Notebook windows.
#
# In Visual Studio Code you can use (Apple-K, Apple-F) or (Command-K, Command-F) to format your html file. This will help clean things up. Use the collapse icons on the left hand gutter to find the chuck of HTML you need to process.

# %%
# results are returned as an iterable list
results = soup.find_all('li', class_="result-row")
results
# Out:
# [<li class="result-row" data-pid="6521745356">
#  <a class="result-image gallery" data-ids="1:00t0t_4UupmMFJOkr,1:00i0i_cUTk0yDV5Z4,1:00F0F_7w3KhOdMqOG,1:00D0D_feYu6zZ2dSq,1:00i0i_k9wMAPdIo6i" href="https://kansascity.craigslist.org/msg/d/fender-acoustic-guitar-dg-3/6521745356.html">
#  <span class="result-price">$80</span>
#  </a>
#  <p class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2018-03-07 09:28" title="Wed 07 Mar 09:28:09 AM">Mar  7</time>
#  <a class="result-title hdrlnk" data-id="6521745356" href="https://kansascity.craigslist.org/msg/d/fender-acoustic-guitar-dg-3/6521745356.html">Fender Acoustic Guitar DG-3</a>
#  <span class="result-meta">
#  <span class="result-price">$80</span>
#  <span class="result-hood"> (South KCMO)</span>
#  <span class="result-tags">
#                      pic
# ...

# %%
for result in results:
    try:
        title = result.find('a', class_="result-title").text
        price = result.a.span.text
        link = result.a['href']

        if (title and price and link):
            print('-------------')
            print(f'{price}. {title}')
            print(link)
    except Exception as e:
        print(e)
# Out:
# -------------
# $80. Fender Acoustic Guitar DG-3
# https://kansascity.craigslist.org/msg/d/fender-acoustic-guitar-dg-3/6521745356.html
# -------------
# $75. fender starcaster acoustic guitar
# https://kansascity.craigslist.org/msg/d/fender-starcaster-acoustic/6514954177.html
# -------------
# $3000. Gretsch Reverend Horton Heat Signature Guitar
# https://kansascity.craigslist.org/msg/d/gretsch-reverend-horton-heat/6512238525.html
# -------------
# $850. 59 Airline Md 8500 Guitar amp
# https://kansascity.craigslist.org/msg/d/59-airline-md-8500-guitar-amp/6509940511.html
# -------------
# $975. T.haruo guitar
# https://kansascity.craigslist.org/msg/d/tharuo-guitar/6506827436.html
# -------------
# $200. IBANEZ AF75-TRS-12-04 ELECTRIC GUITAR
# https://kansascity.craigslist.org/msd/d/ibanez-af75-trselectric-guitar/6521331863.html
# -------------
# $200. Kramer guitar and practice amp
# https://kansascity.craigslist.org/msg/d/kramer-guitar-and-practice-amp/6513286052.html
# ...
