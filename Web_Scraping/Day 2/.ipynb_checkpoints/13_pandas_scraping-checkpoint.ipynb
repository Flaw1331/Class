# %%
import pandas as pd

# %% [markdown]
# We can use the read_html function in Pandas to automatically scrape any tabular data from a page.

# %%
url = 'https://en.wikipedia.org/wiki/List_of_capitals_in_the_United_States'

# %%
tables = pd.read_html(url)
tables

# %% [markdown]
# * instead of a dataframe, what we get in return is a list of dataframes for any tabular data that Pandas found.

# %%
type(tables)
# Out:
# list

# %% [markdown]
# We can slice off any of those dataframes that we want using normal indexing.

# %%
df = tables[0]
df
# Out:
#                                            0   \
# 0                                       State
# 1   Municipal (Within city proper boundaries)
# 2                                     Alabama
# 3                                      Alaska
# 4                                     Arizona
# 5                                    Arkansas
# 6                                  California
# 7                                    Colorado
# 8                                 Connecticut
# 9                                    Delaware
# 10                                    Florida
# 11                                    Georgia
# 12                                     Hawaii
# 13                                      Idaho
# 14                                   Illinois
# 15                                    Indiana
# 16                                       Iowa
# 17                                     Kansas
# 18                                   Kentucky
# ...

# %%
df.columns = ['State', 'Abr.', 'State-hood Rank', 'Capital', 
              'Capital Since', 'Area (sq-mi)', 'Municipal Population', 
              'Metropolitan Population', 'Rank in state', 'Rank in US',  'Notes']

# %%
df
# Out:
#                                         State  \
# 0                                       State
# 1   Municipal (Within city proper boundaries)
# 2                                     Alabama
# 3                                      Alaska
# 4                                     Arizona
# 5                                    Arkansas
# 6                                  California
# 7                                    Colorado
# 8                                 Connecticut
# 9                                    Delaware
# 10                                    Florida
# 11                                    Georgia
# 12                                     Hawaii
# 13                                      Idaho
# 14                                   Illinois
# 15                                    Indiana
# 16                                       Iowa
# 17                                     Kansas
# 18                                   Kentucky
# ...

# %%
df = df.iloc[2:]
df.head()
# Out:
#         State Abr. State-hood Rank      Capital Capital Since Area (sq-mi)  \
# 2     Alabama   AL            1819   Montgomery          1846        155.4
# 3      Alaska   AK            1959       Juneau          1906       2716.7
# 4     Arizona   AZ            1912      Phoenix          1889        474.9
# 5    Arkansas   AR            1836  Little Rock          1821        116.2
# 6  California   CA            1850   Sacramento          1854         97.2
#
#   Municipal Population Metropolitan Population  Rank in state  Rank in US  \
# 2               205764                  374536            2.0       115.0
# 3                31275                     NaN            3.0         NaN
# 4              1445632                 4192887            1.0         5.0
# 5               193524                  877091            1.0       117.0
# 6               466488                 2527123            6.0        35.0
#
#                                                Notes
# ...

# %% [markdown]
# Set the index to the State column

# %%
df.set_index('State', inplace=True)
df.head()
# Out:
#            Abr. State-hood Rank      Capital Capital Since Area (sq-mi)  \
# State
# Alabama      AL            1819   Montgomery          1846        155.4
# Alaska       AK            1959       Juneau          1906       2716.7
# Arizona      AZ            1912      Phoenix          1889        474.9
# Arkansas     AR            1836  Little Rock          1821        116.2
# California   CA            1850   Sacramento          1854         97.2
#
#            Municipal Population Metropolitan Population  Rank in state  \
# State
# Alabama                  205764                  374536            2.0
# Alaska                    31275                     NaN            3.0
# Arizona                 1445632                 4192887            1.0
# Arkansas                 193524                  877091            1.0
# California               466488                 2527123            6.0
#
#             Rank in US                                              Notes
# State
# ...

# %%
df.loc['California']
# Out:
# Abr.                                                                      CA
# State-hood Rank                                                         1850
# Capital                                                           Sacramento
# Capital Since                                                           1854
# Area (sq-mi)                                                            97.2
# Municipal Population                                                  466488
# Metropolitan Population                                              2527123
# Rank in state                                                              6
# Rank in US                                                                35
# Notes                      Supreme Court of California is headquartered i...
# Name: California, dtype: object

# %% [markdown]
# ### Dataframes to HTML
#
# * Pandas also has a `to_html` method that we can use to generate HTML tables from DataFrames.

# %%
html_table = df.to_html()
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Abr.</th>\n      <th>State-hood Rank</th>\n      <th>Capital</th>\n      <th>Capital Since</th>\n      <th>Area (sq-mi)</th>\n      <th>Municipal Population</th>\n      <th>Metropolitan Population</th>\n      <th>Rank in state</th>\n      <th>Rank in US</th>\n      <th>Notes</th>\n    </tr>\n    <tr>\n      <th>State</th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>Alabama</th>\n      <td>AL</td>\n      <td>1819</td>\n      <td>Montgomery</td>\n      <td>1846</td>\n      <td>155.4</td>\n      <td>205764</td>\n      <td>374536</td>\n      <td>2.0</td>\n      <td>115.0</td>\n      <td>Birmingham is the state\'s largest city.</td>\n    </tr>\n    <tr>\n      <th>Alaska</th>\n      <td>AK</td>\n   
# ...

# %% [markdown]
# You may have to strip unwanted newlines to clean up the table.

# %%
html_table.replace('\n', '')
# Out:
# '<table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>Abr.</th>      <th>State-hood Rank</th>      <th>Capital</th>      <th>Capital Since</th>      <th>Area (sq-mi)</th>      <th>Municipal Population</th>      <th>Metropolitan Population</th>      <th>Rank in state</th>      <th>Rank in US</th>      <th>Notes</th>    </tr>    <tr>      <th>State</th>      <th></th>      <th></th>      <th></th>      <th></th>      <th></th>      <th></th>      <th></th>      <th></th>      <th></th>      <th></th>    </tr>  </thead>  <tbody>    <tr>      <th>Alabama</th>      <td>AL</td>      <td>1819</td>      <td>Montgomery</td>      <td>1846</td>      <td>155.4</td>      <td>205764</td>      <td>374536</td>      <td>2.0</td>      <td>115.0</td>      <td>Birmingham is the state\'s largest city.</td>    </tr>    <tr>      <th>Alaska</th>      <td>AK</td>      <td>1959</td>      <td>Juneau</td>      <td>1906</td>      <td>2716.7</td>      <td>31275
# ...

# %% [markdown]
# You can also save the table directly to a file.

# %%
df.to_html('table.html')
