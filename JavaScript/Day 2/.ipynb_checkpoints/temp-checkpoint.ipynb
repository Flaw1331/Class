# %%
import os
import pandas as pd

# %%
file = os.path.join('data', 'census.csv')

# %%
test = pd.read_csv(file)

# %%
test
# Out:
#      Zipcode                        Address  Population  Median Age  \
# 0      15081   South Heights, PA 15081, USA         342        50.2
# 1      20615  Broomes Island, MD 20615, USA         424        43.4
# 2      50201          Nevada, IA 50201, USA        8139        40.4
# 3      84020          Draper, UT 84020, USA       42751        30.4
# 4      39097          Louise, MS 39097, USA         495        58.0
# 5      72315     Blytheville, AR 72315, USA       24120        34.4
# 6       5454         Fairfax, VT 05454, USA        4754        38.7
# 7      53816         Mt Hope, WI 53816, USA         942        33.4
# 8       5483         Sheldon, VT 05483, USA        1481        35.9
# 9      37345        Huntland, TN 37345, USA        2155        46.0
# 10      1922         Byfield, MA 01922, USA        3025        44.4
# 11     95237       Lockeford, CA 95237, USA        3269        38.7
# 12     12429          Esopus, NY 12429, USA         273        38.7
# ...

# %%
test.to_json('test.json', orient='records', lines=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-88d10fe11911> in <module>()
# ----> 1 test.to_json('test.json', orient='row', lines=False)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in to_json(self, path_or_buf, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines)
#    1243                             force_ascii=force_ascii, date_unit=date_unit,
#    1244                             default_handler=default_handler,
# -> 1245                             lines=lines)
#    1246
#    1247     def to_hdf(self, path_or_buf, key, **kwargs):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/json/json.py in to_json(path_or_buf, obj, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines)
#      44         obj, orient=orient, date_format=date_format,
# ...
