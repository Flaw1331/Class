# %%
import pandas as pd
import os

# %%
data_file = os.path.join("Resources", "ted_talks.csv")
ted_df = pd.read_csv(data_file)
ted_df.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event  languages   main_speaker  \
# 0  TED2006         60   Ken Robinson
# 1  TED2006         43        Al Gore
# 2  TED2006         26    David Pogue
# 3  TED2006         35  Majora Carter
# 4  TED2006         48   Hans Rosling
#
#                                             name  \
# 0      Ken Robinson: Do schools kill creativity?
# 1           Al Gore: Averting the climate crisis
# 2                  David Pogue: Simplicity sells
# 3             Majora Carter: Greening the ghetto
# 4  Hans Rosling: The best stats you've ever seen
#
#                              title     views
# 0      Do schools kill creativity?  47227110
# 1      Averting the climate crisis   3200520
# 2                 Simplicity sells   1636292
# 3              Greening the ghetto   1697550
# 4  The best stats you've ever seen  12005869

# %%
# Figure out the minimum and maximum views for a TED Talk
print(ted_df['views'].max())
print(ted_df['views'].min())
# Out:
# 47227110
# 50443

# %%
# Create bins in which to place values based upon TED Talk views
bins = [0,200000,400000,600000,800000,1000000,2000000,3000000,4000000,5000000,50000000]

# Create labels for these bins
group_labels = ["0 to 200k","200k to 400k","400k to 600k","600k to 800k","800k to 1mil","1mil to 2mil",
                "2mil to 3mil","3mil to 4mil","4mil to 5mil","5mil to 50mil"]

# %%
# Slice the Views data and place it into bins
pd.cut(ted_df['views'], bins, labels=group_labels)
# Out:
# 0       5mil to 50mil
# 1        3mil to 4mil
# 2        1mil to 2mil
# 3        1mil to 2mil
# 4       5mil to 50mil
# 5       5mil to 50mil
# 6        3mil to 4mil
# 7        800k to 1mil
# 8        2mil to 3mil
# 9        3mil to 4mil
# 10       1mil to 2mil
# 11       200k to 400k
# 12       600k to 800k
# 13       4mil to 5mil
# 14       200k to 400k
# 15       2mil to 3mil
# 16       1mil to 2mil
# 17       1mil to 2mil
# 18       1mil to 2mil
# 19       1mil to 2mil
# 20       800k to 1mil
# 21      5mil to 50mil
# 22       400k to 600k
# 23      5mil to 50mil
# 24       1mil to 2mil
# 25       1mil to 2mil
# 26       2mil to 3mil
# 27       2mil to 3mil
# 28      5mil to 50mil
# 29      5mil to 50mil
#             ...
# 2520     800k to 1mil
# 2521     600k to 800k
# 2522     600k to 800k
# 2523     600k to 800k
# 2524     400k to 600k
# 2525     600k to 800k
# 2526     600k to 800k
# 2527     600k to 800k
# 2528     400k to 600k
# 2529     800k to 1mil
# 2530     400k to 600k
# 2531     600k to 800k
# 2532     1mil to 2mil
# 2533     200k to 400k
# 2534     600k to 800k
# 2535     600k to 800k
# 2536     400k to 600k
# 2537     1mil to 2mil
# 2538     600k to 800k
# 2539     400k to 600k
# 2540     600k to 800k
# 2541     600k to 800k
# 2542     400k to 600k
# 2543     400k to 600k
# 2544     400k to 600k
# 2545     400k to 600k
# 2546     400k to 600k
# 2547     200k to 400k
# 2548     400k to 600k
# 2549     200k to 400k
# Name: views, Length: 2550, dtype: category
# Categories (10, object): [0 to 200k < 200k to 400k < 400k to 600k < 600k to 800k ... 2mil to 3mil < 3mil to 4mil < 4mil to 5mil < 5mil to 50mil]

# %%
# Place the data series into a new column inside of the DataFrame
ted_df["View Group"] = pd.cut(ted_df['views'],bins, labels=group_labels)
ted_df.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event  languages   main_speaker  \
# 0  TED2006         60   Ken Robinson
# 1  TED2006         43        Al Gore
# 2  TED2006         26    David Pogue
# 3  TED2006         35  Majora Carter
# 4  TED2006         48   Hans Rosling
#
#                                             name  \
# 0      Ken Robinson: Do schools kill creativity?
# 1           Al Gore: Averting the climate crisis
# 2                  David Pogue: Simplicity sells
# 3             Majora Carter: Greening the ghetto
# 4  Hans Rosling: The best stats you've ever seen
#
#                              title     views     View Group
# 0      Do schools kill creativity?  47227110  5mil to 50mil
# 1      Averting the climate crisis   3200520   3mil to 4mil
# 2                 Simplicity sells   1636292   1mil to 2mil
# 3              Greening the ghetto   1697550   1mil to 2mil
# 4  The best stats you've ever seen  12005869  5mil to 50mil

# %%
# Get a count of each bin from the 'View Group' column
ted_df['View Group'].value_counts()
# Out:
# 1mil to 2mil     1004
# 800k to 1mil      339
# 600k to 800k      307
# 2mil to 3mil      239
# 400k to 600k      234
# 200k to 400k      135
# 5mil to 50mil      99
# 3mil to 4mil       93
# 4mil to 5mil       68
# 0 to 200k          32
# Name: View Group, dtype: int64

# %%
# Create a GroupBy object based upon "View Group"
ted_vg = ted_df.groupby("View Group")
ted_vg.max()
# Out:
#                comments                                        description  \
# View Group
# 0 to 200k           208  While we all agree that compassion is a great ...
# 200k to 400k        649  Zambia-born filmmaker Franco Sacchi tours us t...
# 400k to 600k        834  Yves Behar and Forrest North unveil Mission On...
# 600k to 800k        846  “Men fight wars, and women mourn them,” says d...
# 800k to 1mil        831  eL Seed fuses Arabic calligraphy with graffiti...
# 1mil to 2mil       2492  “If you really want to know a people, start by...
# 2mil to 3mil       2673  “People are so afraid of variety that they try...
# 3mil to 4mil       3356  You’re doing everything right at work, taking ...
# 4mil to 5mil       6404  Writer Andrew Solomon has spent his career tel...
# 5mil to 50mil      4553  You've never seen data presented like this. Wi...
#
#                duration                     event  languages  \
# View Group
# 0 to 200k          3573  University of California         30
# 200k to 400k       3475               Taste3 2008         48
# 400k to 600k       5256  University of California         47
# 600k to 800k       2678         Web 2.0 Expo 2008         61
# 800k to 1mil       2853               Taste3 2008         51
# 1mil to 2mil       3608       Toronto Youth Corps         54
# 2mil to 3mil       1485           TEDxZurich 2012         69
# 3mil to 4mil       2018    World Science Festival         56
# 4mil to 5mil       2102               TEDxMidwest         58
# 5mil to 50mil      2450                    TEDxUW         72
#
#                     main_speaker  \
# View Group
# 0 to 200k           Tim Birkhead
# 200k to 400k    Virginia Postrel
# 400k to 600k        Zainab Salbi
# 600k to 800k       Yoruba Richen
# 800k to 1mil             eL Seed
# 1mil to 2mil             eL Seed
# 2mil to 3mil   iO Tillett Wright
# 3mil to 4mil        Yves Morieux
# 4mil to 5mil            Ze Frank
# 5mil to 50mil           Ze Frank
#
#                                                             name  \
# View Group
# 0 to 200k                   Tim Birkhead: The early birdwatchers
# 200k to 400k                        Virginia Postrel: On glamour
# 400k to 600k   Zainab Salbi: Women, wartime and the dream of ...
# 600k to 800k   Yoruba Richen: What the gay rights movement le...
# 800k to 1mil   eL Seed: A project of peace, painted across 50...
# 1mil to 2mil   eL Seed: Street art with a message of hope and...
# 2mil to 3mil              iO Tillett Wright: Fifty shades of gay
# 3mil to 4mil   Yves Morieux: As work gets more complex, 6 rul...
# 4mil to 5mil                            Ze Frank: Are you human?
# 5mil to 50mil                          Ze Frank: Nerdcore comedy
#
#                                                           title     views
# View Group
# 0 to 200k                                      Why I do theater    197139
# 200k to 400k      Would you live in a floating city in the sky?    399332
# 400k to 600k                 You are the future of philanthropy    599444
# 600k to 800k              Your health depends on where you live    799891
# 800k to 1mil    Your company's data could help end world hunger    999700
# 1mil to 2mil                   “Am I dying?” The honest answer.   1999097
# 2mil to 3mil   Your words may predict your future mental health   2991225
# 3mil to 4mil              Yup, I built a nuclear fusion reactor   3982352
# 4mil to 5mil                          Your brain on video games   4984884
# 5mil to 50mil                      Your elusive creative genius  47227110

# %%
# Get the average of each numeric column within the GroupBy object
ted_vg.mean()
# Out:
#                  comments    duration  languages         views
# View Group
# 0 to 200k       76.937500  898.187500   4.062500  1.498010e+05
# 200k to 400k    81.992593  832.192593  18.785185  3.221191e+05
# 400k to 600k   107.162393  870.517094  22.940171  5.038403e+05
# 600k to 800k   118.912052  829.039088  24.400651  7.058367e+05
# 800k to 1mil   119.628319  798.772861  25.678466  9.022959e+05
# 1mil to 2mil   168.136454  809.899402  27.899402  1.368263e+06
# 2mil to 3mil   299.481172  832.430962  32.807531  2.390719e+06
# 3mil to 4mil   360.870968  809.505376  34.258065  3.440350e+06
# 4mil to 5mil   507.088235  920.514706  35.720588  4.468781e+06
# 5mil to 50mil  650.393939  884.282828  40.252525  1.083801e+07
