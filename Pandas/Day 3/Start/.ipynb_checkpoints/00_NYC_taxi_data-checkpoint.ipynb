# %% [markdown]
# # NYC Taxi Data
#
# * http://chriswhong.com/open-data/foil_nyc_taxi/ - Great story about how this data was acquired.
#
# * http://www.andresmh.com/nyctaxitrips/
#
# * Will the passenger tip the driver?

# %%
import pandas as pd
import os
# %matplotlib inline

# %%
file_name = os.path.join("Resources", "taxi_merged.csv")
data = pd.read_csv(file_name)

# %%
data.head()
# Out:
#    Unnamed: 0                         medallion  \
# 0           0  89D227B655E5C82AECF13C3F540D4CF4
# 1           1  0BD7C8F5BA12B88E0B67BED28BEA73D8
# 2           2  0BD7C8F5BA12B88E0B67BED28BEA73D8
# 3           3  DFD2202EE08F7A8DC9A57B02ACB81FE2
# 4           4  DFD2202EE08F7A8DC9A57B02ACB81FE2
#
#                        hack_license vendor_id  rate_code store_and_fwd_flag  \
# 0  BA96DE419E711691B9445D6A6307C170       CMT          1                  N
# 1  9FD8F69F0804BDB5549F40E9DA1BE472       CMT          1                  N
# 2  9FD8F69F0804BDB5549F40E9DA1BE472       CMT          1                  N
# 3  51EE87E3205C985EF8431D850C786310       CMT          1                  N
# 4  51EE87E3205C985EF8431D850C786310       CMT          1                  N
#
#        pickup_datetime     dropoff_datetime  passenger_count  \
# 0  2013-01-01 15:11:48  2013-01-01 15:18:10                4
# 1  2013-01-06 00:18:35  2013-01-06 00:22:54                1
# ...

# %%
tipped.plot(x="pickup_latitude", y="pickup_longitude", kind="scatter", s=0.5,  alpha=0.5, figsize=(16,8), 
          xlim=(40.6, 40.9), ylim=(-74.02, -73.9))

# %%
import matplotlib
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(15, 15))
plt.plot(tipped["dropoff_latitude"], tipped["dropoff_longitude"], 'b,')
plt.plot(no_tip["dropoff_latitude"], no_tip["dropoff_longitude"], 'r,')

plt.xlim(40.6, 40.9)
plt.ylim(-74.05, -73.9)
# Out:
# (-74.05, -73.9)
