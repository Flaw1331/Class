# %%
import pandas as pd
import os

# %%
csv_path = os.path.join("Resources", "flavors_of_cacao.csv")
chocolate_ratings_df = pd.read_csv(csv_path)
chocolate_ratings_df.head(10)
# Out:
#   Company (Maker-if known) Specific Bean Origin or Bar Name   REF  \
# 0                 A. Morin                      Agua Grande  1876
# 1                 A. Morin                            Kpime  1676
# 2                 A. Morin                           Atsane  1676
# 3                 A. Morin                            Akata  1680
# 4                 A. Morin                           Quilla  1704
# 5                 A. Morin                         Carenero  1315
# 6                 A. Morin                             Cuba  1315
# 7                 A. Morin                     Sur del Lago  1315
# 8                 A. Morin                   Puerto Cabello  1319
# 9                 A. Morin                          Pablino  1319
#
#    Review Date Cocoa Percent Company Location  Rating Bean Type  \
# 0         2016           63%           France    3.75
# 1         2015           70%           France    2.75
# 2         2015           70%           France    3.00
# ...

# %%
chocolate_ratings_df.hist(bins=30,figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x125619da0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12890ba90>]], dtype=object)

# %%
chocolate_ratings_df.hist(column='Rating', bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12950b898>]], dtype=object)

# %%
chocolate_ratings_df['Rating'].describe()
# Out:
# count    1795.000000
# mean        3.185933
# std         0.478062
# min         1.000000
# 25%         2.875000
# 50%         3.250000
# 75%         3.500000
# max         5.000000
# Name: Rating, dtype: float64

# %%
chocolate_ratings_df.groupby(
    chocolate_ratings_df['Company Location'])['Rating'].mean().plot(
    kind='bar', figsize=(14,6))

# %%
chocolate_ratings_df.groupby(
    chocolate_ratings_df['Broad Bean Origin'])['Rating'].mean().plot(
    kind='bar', figsize=(20,6))

# %%
chocolate_ratings_df.columns
# Out:
# Index(['Company (Maker-if known)', 'Specific Bean Origin or Bar Name', 'REF',
#        'Review Date', 'Cocoa Percent', 'Company Location', 'Rating',
#        'Bean Type', 'Broad Bean Origin'],
#       dtype='object')

# %%
# Finding the average cocoa 
chocolate_ratings_df["Cocoa Percent"].mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#     767         try:
# --> 768             x = float(x)
#     769         except Exception:
#
# ...

# %%
chocolate_ratings_df['Cocoa Percent'].describe()
# Out:
# count     1795
# unique      45
# top        70%
# freq       672
# Name: Cocoa Percent, dtype: object

# %%
chocolate_ratings_df['Cocoa Percent'] = chocolate_ratings_df['Cocoa Percent'].str.rstrip("%").astype('float')

# %%
chocolate_ratings_df['Cocoa Percent'].head()
# Out:
# 0    63.0
# 1    70.0
# 2    70.0
# 3    70.0
# 4    70.0
# Name: Cocoa Percent, dtype: float64

# %%
chocolate_ratings_df['Cocoa Percent'].mean()
# Out:
# 71.6983286908078
